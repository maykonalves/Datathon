# %%
import os
import json
import pandas as pd
import re
import unicodedata
import numpy as np

# %%
FILE = '../data/raw/applicants.json'

def load_json(path):
    with open(path, 'r', encoding='utf-8') as f:
        return json.load(f)

# Applicants
data = load_json(FILE)
df = pd.DataFrame([
    {
        'candidato_id': cid,
        **data.get('infos_basicas', {}),
        **data.get('formacao_e_idiomas', {}),
        **data.get('informacoes_profissionais', {}),
        'cv_pt': data.get('cv_pt'),
    }
    for cid, data in data.items()
])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42482 entries, 0 to 42481
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   candidato_id                 42482 non-null  object
#  1   telefone_recado              42482 non-null  object
#  2   telefone                     42482 non-null  object
#  3   objetivo_profissional        42482 non-null  object
#  4   data_criacao                 42482 non-null  object
#  5   inserido_por                 42482 non-null  object
#  6   email                        42482 non-null  object
#  7   local                        42482 non-null  object
#  8   sabendo_de_nos_por           42482 non-null  object
#  9   data_atualizacao             42482 non-null  object
#  10  codigo_profissional          42482 non-null  object
#  11  nome                         42482 non-null  object
#  12  nivel_academico              42482 non-null  object
#  13  nivel_ingles                 42482 non-null  object
#  14  nivel_espanhol               42482 non-null  object
#  15  outro_idioma                 42482 non-null  object
#  16  titulo_profissional          42482 non-null  object
#  17  area_atuacao                 42482 non-null  object
#  18  conhecimentos_tecnicos       42482 non-null  object
#  19  certificacoes                42482 non-null  object
#  20  outras_certificacoes         42482 non-null  object
#  21  remuneracao                  42482 non-null  object
#  22  nivel_profissional           42482 non-null  object
#  23  cv_pt                        42482 non-null  object
#  24  instituicao_ensino_superior  7209 non-null   object
#  25  cursos                       7209 non-null   object
#  26  ano_conclusao                7209 non-null   object
#  27  outro_curso                  809 non-null    object
#  28  qualificacoes                944 non-null    object
#  29  experiencias                 944 non-null    object
# dtypes: object(30)
# memory usage: 9.7+ MB

# %%
df.columns
# Out:
# Index(['candidato_id', 'telefone_recado', 'telefone', 'objetivo_profissional',
#        'data_criacao', 'inserido_por', 'email', 'local', 'sabendo_de_nos_por',
#        'data_atualizacao', 'codigo_profissional', 'nome', 'nivel_academico',
#        'nivel_ingles', 'nivel_espanhol', 'outro_idioma', 'titulo_profissional',
#        'area_atuacao', 'conhecimentos_tecnicos', 'certificacoes',
#        'outras_certificacoes', 'remuneracao', 'nivel_profissional', 'cv_pt',
#        'instituicao_ensino_superior', 'cursos', 'ano_conclusao', 'outro_curso',
#        'qualificacoes', 'experiencias'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        print(f"Column '{col}' has {df[col].nunique()} unique values.")
# Out:
# Column 'candidato_id' has 42482 unique values.
# Column 'telefone_recado' has 1 unique values.
# Column 'telefone' has 41026 unique values.
# Column 'objetivo_profissional' has 8368 unique values.
# Column 'data_criacao' has 41708 unique values.
# Column 'inserido_por' has 63 unique values.
# Column 'email' has 41482 unique values.
# Column 'local' has 721 unique values.
# Column 'sabendo_de_nos_por' has 14 unique values.
# Column 'data_atualizacao' has 41761 unique values.
# Column 'codigo_profissional' has 42482 unique values.
# Column 'nome' has 40686 unique values.
# Column 'nivel_academico' has 22 unique values.
# Column 'nivel_ingles' has 6 unique values.
# Column 'nivel_espanhol' has 6 unique values.
# Column 'outro_idioma' has 33 unique values.
# Column 'titulo_profissional' has 8368 unique values.
# Column 'area_atuacao' has 838 unique values.
# Column 'conhecimentos_tecnicos' has 3190 unique values.
# Column 'certificacoes' has 270 unique values.
# Column 'outras_certificacoes' has 884 unique values.
# Column 'remuneracao' has 3703 unique values.
# Column 'nivel_profissional' has 11 unique values.
# Column 'cv_pt' has 28731 unique values.
# Column 'instituicao_ensino_superior' has 682 unique values.
# Column 'cursos' has 158 unique values.
# Column 'ano_conclusao' has 80 unique values.
# Column 'outro_curso' has 1 unique values.
# Column 'qualificacoes' has 2 unique values.
# Column 'experiencias' has 2 unique values.

# %%
df = df.drop(
    [
    'telefone_recado',
    'telefone',
    'data_criacao',
    'inserido_por',
    'email',
    'data_atualizacao',
    'codigo_profissional',
    'outro_curso',
    'qualificacoes',
    'experiencias',
    'remuneracao'
    ]
    , axis=1)

# %%
for column in df.columns:
    if df[column].nunique() < 35:
        print(f"Column '{column}' unique values: {df[column].unique()}")
# Out:
# Column 'sabendo_de_nos_por' unique values: ['' 'Outros' 'Anúncio' 'Site de Empregos' 'Indeed'
#  'Indicação de colaborador' 'Nosso site' 'Indicação de amigo'
#  'Escolas/Faculdades' 'Indicação de cliente' 'Evento universitário'
#  'ONG/PAT/CAT' 'Feira de RH' 'Plaqueiro']
# Column 'nivel_academico' unique values: ['' 'Ensino Superior Incompleto' 'Ensino Superior Completo'
#  'Ensino Técnico Completo' 'Ensino Superior Cursando'
#  'Pós Graduação Completo' 'Pós Graduação Cursando'
#  'Pós Graduação Incompleto' 'Ensino Técnico Cursando'
#  'Ensino Fundamental Completo' 'Ensino Médio Completo'
#  'Doutorado Completo' 'Mestrado Completo' 'Mestrado Incompleto'
#  'Mestrado Cursando' 'Doutorado Incompleto' 'Ensino Técnico Incompleto'
#  'Ensino Médio Cursando' 'Ensino Médio Incompleto'
#  'Ensino Fundamental Cursando' 'Doutorado Cursando'
#  'Ensino Fundamental Incompleto']
# Column 'nivel_ingles' unique values: ['' 'Nenhum' 'Intermediário' 'Básico' 'Avançado' 'Fluente']
# Column 'nivel_espanhol' unique values: ['' 'Nenhum' 'Básico' 'Intermediário' 'Avançado' 'Fluente']
# Column 'outro_idioma' unique values: ['-' 'Português - Fluente' 'Francês - Intermediário' 'Francês - Básico'
#  'Italiano - Avançado' 'Português -' 'Italiano - Básico'
#  'Português - Avançado' 'Alemão - Básico' 'Alemão -' 'Japonês - Básico'
#  'Japonês -' 'Alemão - Avançado' 'Japonês - Avançado'
#  'Alemão - Intermediário' 'Russo - Básico' 'Russo - Intermediário'
#  'Italiano - Intermediário' 'Português - Intermediário'
#  'Japonês - Intermediário' 'Mandarim - Básico' 'Francês - Avançado'
#  'Português - Nenhum' 'Italiano -' 'Português - Básico'
#  'Francês - Fluente' 'Italiano - Fluente' 'Japonês - Fluente'
#  'Japonês - Nenhum' 'Russo - Fluente' 'Alemão - Nenhum' 'Francês -'
#  'Alemão - Fluente']
# Column 'nivel_profissional' unique values: ['' 'Sênior' 'Especialista' 'Júnior' 'Pleno' 'Analista' 'Gerente' 'Líder'
#  'Outro' 'Técnico de Nível Médio' 'Estagiário']

# %%
df = df.drop(
     [
     'sabendo_de_nos_por'
     ]
     , axis=1)

# %%
df.nivel_profissional.value_counts(normalize=True) * 100
# Out:
# nivel_profissional
#                           99.811685
# Sênior                     0.065910
# Analista                   0.040017
# Pleno                      0.025893
# Especialista               0.018832
# Júnior                     0.016478
# Líder                      0.009416
# Técnico de Nível Médio     0.004708
# Gerente                    0.002354
# Outro                      0.002354
# Estagiário                 0.002354
# Name: proportion, dtype: float64

# %%
df = df.drop( 'nivel_profissional', axis=1)

# %%
df.columns
# Out:
# Index(['candidato_id', 'objetivo_profissional', 'local', 'nome',
#        'nivel_academico', 'nivel_ingles', 'nivel_espanhol', 'outro_idioma',
#        'titulo_profissional', 'area_atuacao', 'conhecimentos_tecnicos',
#        'certificacoes', 'outras_certificacoes', 'nivel_profissional', 'cv_pt',
#        'instituicao_ensino_superior', 'cursos', 'ano_conclusao'],
#       dtype='object')

# %%
for col in df.columns:
    print(df[col].value_counts(normalize=True) * 100)
    print("=" * 60)
# Out:
# candidato_id
# 5999     0.002354
# 31000    0.002354
# 5983     0.002354
# 5982     0.002354
# 5981     0.002354
#            ...
# 31006    0.002354
# 31005    0.002354
# 31004    0.002354
# 31003    0.002354
# 31002    0.002354
# Name: proportion, Length: 42482, dtype: float64
# ============================================================
# objetivo_profissional
#                                            33.934372
# Java                                        1.555953
# Gerente de Projetos                         1.428840
# Suporte                                     1.275834
# Desenvolvedor                               1.113413
#                                              ...
# Desenvolvedor Dot Net                       0.002354
# Administrativa/logística e ou comercial     0.002354
# BigData                                     0.002354
# Gerente TI                                  0.002354
# Analista de planejamento                    0.002354
# Name: proportion, Length: 8368, dtype: float64
# ============================================================
# local
#                                   59.964220
# São Paulo, São Paulo              15.265289
# Rio de Janeiro, Rio de Janeiro     1.996140
# Fortaleza, Ceará                   1.876089
# Campinas, São Paulo                1.388824
#                                     ...
# Capixaba, Acre                     0.002354
# Sanclerlândia, Goiás               0.002354
# Mato Grosso                        0.002354
# São Marcos, Rio Grande do Sul      0.002354
# Palmas, Paraná                     0.002354
# Name: proportion, Length: 721, dtype: float64
# ============================================================
# nome
# Ágatha da Costa               0.023539
# Srta. Luísa Silveira          0.014124
# João Felipe Pimenta           0.014124
# Srta. Maria Cecília Garcia    0.014124
# Dr. Liam Costa                0.014124
#                                 ...
# Gabrielly Novaes              0.002354
# Sr. Gabriel Rios              0.002354
# Dr. Mathias da Cunha          0.002354
# Bruna Vieira                  0.002354
# Paulo Novaes                  0.002354
# Name: proportion, Length: 40686, dtype: float64
# ============================================================
# nivel_academico
#                                  80.947225
# Ensino Superior Completo          8.318817
# Pós Graduação Completo            4.267690
# Ensino Superior Cursando          2.111483
# Ensino Superior Incompleto        0.981592
# Ensino Médio Completo             0.943929
# Pós Graduação Cursando            0.680288
# Ensino Técnico Completo           0.529636
# Mestrado Completo                 0.386046
# Pós Graduação Incompleto          0.350737
# Ensino Técnico Cursando           0.127113
# Mestrado Incompleto               0.077680
# Mestrado Cursando                 0.063556
# Ensino Fundamental Completo       0.056495
# Ensino Técnico Incompleto         0.040017
# Doutorado Completo                0.028247
# Ensino Médio Incompleto           0.023539
# Ensino Médio Cursando             0.021185
# Doutorado Incompleto              0.018832
# Ensino Fundamental Cursando       0.009416
# Doutorado Cursando                0.009416
# Ensino Fundamental Incompleto     0.007062
# Name: proportion, dtype: float64
# ============================================================
# nivel_ingles
#                  83.889647
# Intermediário     5.275175
# Básico            4.936208
# Avançado          3.220187
# Nenhum            1.398239
# Fluente           1.280542
# Name: proportion, dtype: float64
# ============================================================
# nivel_espanhol
#                  84.259216
# Básico            6.972365
# Nenhum            5.286945
# Intermediário     2.132668
# Avançado          0.774446
# Fluente           0.574361
# Name: proportion, dtype: float64
# ============================================================
# outro_idioma
# -                            96.673885
# Português - Fluente           1.560661
# Francês - Básico              0.306012
# Português -                   0.303658
# Alemão - Básico               0.145944
# Italiano - Básico             0.134174
# Português - Avançado          0.122405
# Francês - Intermediário       0.103573
# Japonês - Básico              0.101219
# Italiano - Intermediário      0.070618
# Francês - Avançado            0.058848
# Japonês - Intermediário       0.051787
# Português - Intermediário     0.047079
# Italiano - Avançado           0.044725
# Alemão - Intermediário        0.044725
# Português - Básico            0.040017
# Francês - Fluente             0.035309
# Italiano - Fluente            0.023539
# Alemão - Avançado             0.018832
# Italiano -                    0.018832
# Português - Nenhum            0.014124
# Japonês -                     0.011770
# Mandarim - Básico             0.011770
# Russo - Básico                0.011770
# Francês -                     0.009416
# Alemão -                      0.007062
# Japonês - Avançado            0.007062
# Alemão - Fluente              0.007062
# Russo - Fluente               0.004708
# Russo - Intermediário         0.002354
# Japonês - Fluente             0.002354
# Japonês - Nenhum              0.002354
# Alemão - Nenhum               0.002354
# Name: proportion, dtype: float64
# ============================================================
# titulo_profissional
#                                            33.934372
# Java                                        1.555953
# Gerente de Projetos                         1.428840
# Suporte                                     1.275834
# Desenvolvedor                               1.113413
#                                              ...
# Desenvolvedor Dot Net                       0.002354
# Administrativa/logística e ou comercial     0.002354
# BigData                                     0.002354
# Gerente TI                                  0.002354
# Analista de planejamento                    0.002354
# Name: proportion, Length: 8368, dtype: float64
# ============================================================
# area_atuacao
#                                                                                                                                                                                                                                             84.108564
# TI - Desenvolvimento/Programação                                                                                                                                                                                                             2.556377
# Administrativa                                                                                                                                                                                                                               2.135022
# TI - SAP                                                                                                                                                                                                                                     1.172261
# TI - Projetos                                                                                                                                                                                                                                0.854480
#                                                                                                                                                                                                                                               ...
# Gestão e Alocação de Recursos de TI, TI - Infraestrutura, TI - Processos e Negócios, TI - Projetos, TI - Suporte                                                                                                                             0.002354
# TI - Banco de Dados, TI - Governança, TI - Processos e Negócios, TI - Projetos                                                                                                                                                               0.002354
# TI - Arquitetura, TI - Banco de Dados, TI - Desenvolvimento/Design, TI - Desenvolvimento/Mobile, TI - Desenvolvimento/Programação, TI - Governança, TI - Infraestrutura, TI - Processos e Negócios, TI - Projetos, TI - Qualidade/Testes     0.002354
# TI - SAP, TI - Sistemas e Ferramentas, TI - Suporte                                                                                                                                                                                          0.002354
# Gestão e Alocação de Recursos de TI, TI - Desenvolvimento/Programação, TI - Infraestrutura, TI - Suporte                                                                                                                                     0.002354
# Name: proportion, Length: 838, dtype: float64
# ============================================================
# conhecimentos_tecnicos
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 92.107245
# • Consultor Funcional especializado em Material Management (Administração de materiais) e Warehouse Management (Administração de Depósito). • Trajetória profissional como consultor de informática e consultor de negócios, com pleno conhecimentos de estruturas empresariais, ciclos de processos administrativos logisticos e industriais. • Instrutor em treinamento à usuários e pessoal técnico, certificado pela Unisys do Brasil em treinamento. • Solida experiência em implantação de pacotes ERP, tais como BAAN e SAP R/3. • Implantação de SAP R/3 participando de processos de levantamentos, análise de aderência, customização, implantações, definição de interfaces e treinamento à usuários. • Conhecimentos de QM (notas de qualidade, decisão utilização, controles de lotes, etc) e PP • Conhecimento ABAP e LSMW • Conhecimento dos processos de SD (Pedidos, Picking, Pecking, etc) • Experiencia em projetos internacionais (Estados Unidos, Cidra-Porto Rico ,Argentina , Alemanha, Dinamarca e Colombia). • Experiencia em localização Brasil. TAXBRJ e TAXBRA. • Experiencia em localização Chile (TAXCL) e Colômbia (TAXCO)                                                                                                                                                                                                                        0.014124
# Profissional possui 10 anos de experiência em implementação de SAP R/3 módulos SAP MM, WM, SD, FI TV com participação de projetos de full-implementation (Telemar ) e projetos de melhorias e suporte (Petrobras). Responsável por atividades que envolvem Localização Brasil TAXBRA, TAXBRJ, processos de subcontratação, desenho e redesenho de processos, configurações, elaboração de especificações funcionais, execução de testes, carga de dados mestres, treinamento à key-users e suporte funcional, cadastro de materiais Retail.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.014124
# Qualidade Ferramentas Gerenciais da Qualidade, desenvolvimento, homologação e avaliação de matéria-prima e fornecedores, Auditor Interno ISO 9001-2008. Gestão de Indicadores de Eficácia e Eficiência; treinamento de conscientização na Qualidade; gestão de treinamentos internos (RH); planejamento, controle e execução de auditorias internas de manutenção e emissão de relatórios de auditorias; tratamento de reclamações de clientes; abertura e tratamento de não-conformidade; manutenção de documentos referentes à qualidade; implantação de SGQ; elaboração de instruções de trabalhos, procedimentos e fluxograma; otimização de fluxo de processos; elaboração de PPAP, FEMEA, IMDS e relatórios de Capabilidade. Informática Aplicações de Escritório: Microsoft Office (Nível Intermediário a Avançado); montagem, configuração e manutenção de Microcomputadores; montagem de redes internas, mapeamento de rede e administração de rede interna; cronograma de implantação de software de gestão empresarial (ERP); Access com VBA; Excel avançado; Análise de Sistemas; Bizagi Modeler; Banco de dados: SQL Server/MySQL (Criação e Manutenção; Stored Procedure, Triggers e Views); Programação Orientada a Objetos: C# (Windows Forms, CRUD) Código fonte e interface gráfica; Java: Básico; Android Studio: Básico; Sistemas Operacionais: Windows.     0.011770
# Programação Abap:  Criação de Reports, ModulePool, Sapscript, Smartforms, BatchInput, Field-Exits, User-Exits, XML, Enhancements, BADI, BAPI e etc).  Participação em projetos de Implementação, Migração, Support Package, Sap Notes, NF-e, CT-e, nas versões 4.7 e ECC 6.  Amplo conhecimento técnico e funcional no sistema PW.CE nos módulos de Comércio Exterior (Importação, Exportação e Câmbio).  Criação de Especificações e detalhamento técnico.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.009416
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
#  MAINFRAME / MVS / VSAM / CICS / ROSCOE / TSO / CA-VIEW / IDMS / JCL / VIEWESP  VM / CMS / XEDIT / SQL / JOBTRAC                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.002354
# Conhecimento avançado em redes, servidores e ambientes virtualizados e Cloud Azure e AWS. Conhecimento avançado em Microsoft Office, gerenciamento de Antivírus, Backup (Data Protector, Commvault), firewall, gerenciamento de rede e ferramentas de monitoração. Conhecimento básico em clusters, banco de dados e gerenciamento de projetos. Experiência como professor e instrutor técnico de redes, hardware, Linux e CISCO.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.002354
#  Java (SE e EE): Básico;  JavaFX e SceneBuilder: Básico;  Banco de Dados Relacionais (MySQL, JDBC, PostgreSQL, H2): Básico;  Banco de Dados Não-Relacionais (MongoDB): Básico;  Frameworks (Hibernate, Spring): Básico;  APIs (Restful, JPA): Básico;  IDE Eclipse: Básico;  GIT e GITHub: Básico;  Servidores Web (Apache, Maven, Tomcat, JBoss, Wildfly): Básico;  Metodologias Ágeis: Básico;  Serviços em Nuvem (Azure, AWS): Básico.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.002354
# SQL, Jira, Pacote Office, Modelagem de Processos (Bizagi)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.002354
# Roteadores, Switches.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.002354
# Name: proportion, Length: 3190, dtype: float64
# ============================================================
# certificacoes
#                                                                                                                                                                                                         98.757121
# ITIL v3 - IT Infraestructure Library                                                                                                                                                                     0.120051
# PMP - Project Management Professional                                                                                                                                                                    0.091804
# Agile Product Lifecycle Management 9 Certified Implementation Specialist                                                                                                                                 0.054141
# ITIL v2 - IT Infraestructure Library                                                                                                                                                                     0.037663
#                                                                                                                                                                                                           ...
# SAP SD, SAB ABAP                                                                                                                                                                                         0.002354
# Cisco Certified Design Professional - CCDP                                                                                                                                                               0.002354
# Cisco Certified Design Associate - CCDA                                                                                                                                                                  0.002354
# MS [77-418] MOS: Microsoft Office Word 2013, MS [77-420] MOS: Microsoft Office Excel 2013, MS [77-423] MOS: Microsoft Office Outlook 2013, MS [77-422] MOS: Microsoft Office PowerPoint 2013, SAP FI     0.002354
# Oracle Certified Professional, Java EE 5 Business Component Developer                                                                                                                                    0.002354
# Name: proportion, Length: 270, dtype: float64
# ============================================================
# outras_certificacoes
#                                                                                                                                                                                                       97.883810
# Scrum Foundation Professional Certificate (SFPC)                                                                                                                                                       0.009416
# Scrum Fundamentals Certified                                                                                                                                                                           0.009416
# Scrum Master                                                                                                                                                                                           0.007062
# Scrum Foundation Professional Certificate                                                                                                                                                              0.007062
#                                                                                                                                                                                                         ...
# LGPD para correspondente: instituto Febraban de educação 2023 PLDFT para correspondente: instituto Febraban de educação 2023 Introdução ao direito imobiliário: fundação Getúlio Vargas 2022     0.002354
# Windows word Excel básico                                                                                                                                                                              0.002354
# • Montagem e Manutenção de Micros • Montagem e Manutenção de Redes • Pacote Office / Internet • Excel Avançado/VBA • Windows XP / Windows 2000 / Windows 7 / Windows 10                                0.002354
# ACADEMIA SAP HCM E FOLHA DE PAGAMENTO                                                                                                                                                                  0.002354
# SAP, DN4,MICROSIGA,TOTVS                                                                                                                                                                               0.002354
# Name: proportion, Length: 884, dtype: float64
# ============================================================
# nivel_profissional
#                           99.811685
# Sênior                     0.065910
# Analista                   0.040017
# Pleno                      0.025893
# Especialista               0.018832
# Júnior                     0.016478
# Líder                      0.009416
# Técnico de Nível Médio     0.004708
# Gerente                    0.002354
# Outro                      0.002354
# Estagiário                 0.002354
# Name: proportion, dtype: float64
# ============================================================
# cv_pt
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# em anexo\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# \n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# anexo\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# ...
# campinas, são paulo,\n\nsap abap/workflow consultant\n\nsobre\n• desenvolvedor sap desde 2006.\n• experiência com abap, workflow, enhancements, proxy, idoc, badi, bapi, fieldexit, userexit, module pool, lsmw, batch input, reports, oo, interfaces, módulos de função, rfc, proxy, aplicação de notas, tabelas, sapscript, smartforms\n• documentação técnica, de testes, dentre outras, focando em reutilização de código, comentários e performance.\n• conhecimentos em hcp, gateway, fiori, sapui5, eclipse, screen personas, sap hana para abap, asp, php, java.\n• aplicação de melhores práticas em processos e projetos.\n• inglês intermediário / espanhol básico\n\nexperiencia\n\nsap abap consultant\nnome da empresaessence tempo integral\nperíodo do empregomai. de 2020 – o momento\nduração1 ano 7 meses\nlocalidadesanta catarina, brasil\nblend it consultoria\nsap abap consultant\nnome da empresablend it consultoria\nperíodo do empregonov. de 2017 – mai. de 2020\nduração2 anos 7 meses\nlocalidadepiracicaba e região, brasil\nmsys consultoria\nsap abap consultant\nnome da empresamsys consultoria\nperíodo do empregomar. de 2015 – nov. de 2017\nduração2 anos 9 meses\nlocalidadecampinas e região, brasil\njá com grande conhecimento na área, atuo como desenvolvedor sênior, buscando sempre a solução mais eficaz a ser aplicada, além de me integrar com novas áreas e aprender novas tecnologias.\ntech mahindra complex\nsap abap/workflow consultant\nnome da empresatech mahindra complex\nperíodo do empregoset. de 2007 – mar. de 2015\nduração7 anos 7 meses\nlocalidadesão paulo/sp, brasil\ninicialmente na fábrica de software fui evoluindo e então atuando principalmente em projetos.\nsempre conquistando meu espaço com responsabilidade.\nparticipei de conquistas de selo de qualidade e gerenciei projetos por um curto período.\nno período em que fiquei na fábrica de software, pude atender uma infinidade de clie\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# ribeirão preto, são paulo\n\nsobre\nconsultor especialista em sap abap, com atuação direta em desenvolvimento por mais de seis anos em empresas de diversos ramos como agronegócio, indústria, telefonia, automobilístico, construção civil, alimentícia, serviços, cooperativa, entre outros.\n\nexperiência em toda rotina de implementação, rollout, melhorias e suporte dentro dos projetos sap.\n\natuação também como líder de equipe técnica de desenvolvimento abap, quando necessário.\n\nexperiência em desenvolvimentos nos módulos pp, mm, sd, fi, co, pm, ps, qm e les.\n\n\n- academia oficial sap abap (netweaver 7.0) de 160 horas em 2012.\n- graduado em tecnologia da informação em 1998.\n- pós-graduado em logística integrada em 2007.\n- pós-graduado em gerenciamento de projetos em 2009.\n- graduando em engenharia da computação, conclusão em 2022.\n\n\n\nsenior sap abap consultant\nnome da empresainetum tempo integral\nperíodo do empregoabr. de 2021 – o momento\nduração8 meses\nlocalidadeportugal\nsenior sap abap consultant.\navannt consultoria\nsenior sap abap consultant\nnome da empresaavannt consultoria tempo integral\nperíodo do empregojul. de 2017 – abr. de 2021\nduração3 anos 10 meses\nlocalidaderibeirão preto e região, brasil\nimplantação de 3 projetos s/4hana e 1 projeto ecc. desenvolvimento de gaps identificados pelos funcionais nos projetos. realização de testes unitários e integrados. avaliação de estimativas de desenvolvimentos. aplicação de notas sap. criação de documentações técnicas. atendimento a chamados no ams, utilizando solman. desenvolvimento de pequenos projetos e melhorias no tdf (localização brasil, sped fiscal, contribuições, reinf, ecd, ecf e ciap) e banco de dados hana. atuações pontuais com pi e workflow. análises de melhoria de performance (tunning) de programas. atuação presencial e remoto.\nver menos\nmelitta do brasil\nsenior sap abap consultant\nnome da empresamelitta do brasil tempo integral\nperíodo do empregomar. de 2016 – jul. de 2017\nduração1 ano 5 meses\nlocalidadesão paulo area, brazil\nsr sap abap consultant.\nlevantamento, avaliação, estimativa e desenvolvimento de tarefas de melhorias e estabilização do ambiente sap. desenvolvimento de interfaces com sistemas legados, utilizando pi/po via webservice, jdbc e abap proxy. orientação aos funcionais sobre recursos técnicos sap. coordenação e quality assurance de desenvolvimentos realizados por desenvolvedores abap presenciais e em fábrica de software de consultorias parceiras. realização de testes unitários e integrados. criação de documentações técnicas.\nver menos\nagile solutions\nsap abap team leader\nnome da empresaagile solutions tempo integral\nperíodo do empregonov. de 2013 – jan. de 2016\nduração2 anos 3 meses\nlocalidadesão paulo area, brazil\ncoordenação de equipe de desenvolvimento com 8 recursos abap (presenciais e remotos). entrevistas de novos recursos abap. entendimento e avaliação de gaps. estimativa de tempo e recursos. criação de documento único para especificação funcional e técnica. mapeamento e controle de atividades de desenvolvimento. controle de tempos e recursos. reuniões de feedback com o cliente e com a consultoria. avaliação técnica e de padronização do código abap. orientações técnicas aos recursos da equipe. instrutor em treinamento para equipe interna de desenvolvedores abap do cliente. atendimento e controle de chamados e issues no solman. atuação também como desenvolvedor abap. testes unitários e integrados. criação de especificações técnicas.\nver menos\napice consultoria\nsap abap consultant\nnome da empresaapice consultoria tempo integral\nperíodo do empregoabr. de 2013 – nov. de 2013\nduração8 meses\nlocalidadesão paulo area, brazil\nconsultor sap abap (consultor pj)\n- alocado diretamente no cliente hochtief do brasil em são paulo/sp para projeto de upgrade da versão do sap de 4.6c para ecc 6.0 ehp6.\n- atividades: bbp (business blueprint, as-is e to-be), criação de objetos, elementos de dados, domínios, tabelas ...
# brasileira\n41 anos, casada\nobjetivo: administrativa/ logística e comercial\nformação acadêmica\n logística - uninove (concluído em 2011).\n turismo - unip (incompleto - 2003).\n técnico em publicidade e propaganda - colégio radial (concluído em 1998).\nsíntese de qualificações\n experiência e vivência operacional de e-commerce/ marketplace.\n negociação comercial/ hunter/ prospecção e tratamento de leads de clientes, atendimento\naos fornecedores e suporte às lojas.\n acompanhamento e ajustes de parâmetros de estoques dos principais itens de venda,\ncadastro de produtos e de tabela de novos custos.\n análise de dados e acompanhamento de indicadores de desempenho, performances,\nentrega de estratégias de vendas.\n contribuição para o alcance e superação das metas de faturamento, volume e market\nshare.\nexperiência profissional\n- 05/2019 – 09/2020 sociedade da mesa comércio de vinhos ltda.\natendente e-commerce\n- 11/2017 – 04/2019 panorama embalagens\nanalista de operações – e-commerce\nanalista de operações comerciais\n- 05/2013 – 10/2013 grupo ambipar – unidade de negócios tnl\nanalista comercial\n- 09/2012 – 04/2013 rodoviário goyaz\nexecutiva de contas\natividades desempenhadas\n responsável pela prospecção de novos clientes, abertura de clientes em segmentos\nfaturamento.\n operacionalização de e-commerce, compreendendo mídias sociais, controle as redes\nsociais, chats, dentre outras.\n elaboração e apresentação das propostas comerciais, bem como, condução de reuniões\ncomerciais e administrativas.\n atendimento e-commerce, cobrança, atualização de cadastro, vendas online, toda função\npertinente a área de atendimento online.\n acompanhamento de projetos junto aos clientes, realizando a interface com a operação –\nparticipação ativa na etapa de implantação e coordenação de operações\n participação na definição dos planos estratégicos junto com a equipe de inteligência de\nmercado e membros da diretoria – escopo de atuação, definição dos setores, estratégia\nde manutenção dos clientes, interface com as áreas operacionais.\n realização e acompanhamento pós-vendas, sendo responsável pelo levantamento de\nproblemas, definição de planos de ação e acompanhamento das resoluções junto as áreas\noperacionais, financeiras e administrativas.\nprincipais prospectos e desenvolvimento de projetos de melhoria contínua nos clientes\nativos.\n mapeamento da ação e serviços dos concorrentes e participação em eventos do\nsegmento.\n monitoramento dos contratos, reuniões de mensais de acompanhamento, elaboração\ndos indicadores, controle de registros e informações no crm – controle de estoque e\nníveis de serviço operacionais.\ninformática\n informática – word, excel, powerpoint e internet explorer.\n sistemas erp’s: totvs\ncursos extracurriculares\n inglês e espanhol básico.\n controle de qualidade ao cliente (iso9001) – banco santander.\n análise de planejamento financeiro – sebrae.\n empreendedor individual – sebrae.\n técnica de vendas – catho\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# Name: proportion, Length: 28731, dtype: float64
# ============================================================
# instituicao_ensino_superior
#                                                     82.674435
# FIAP                                                 0.638091
# Universidade Paulista                                0.360660
# FGV                                                  0.360660
# Universidade Estácio de Sá                           0.319046
#                                                       ...
# Unib                                                 0.013872
# SP -> Universidade Cruzeiro do Sul - UNICSUL         0.013872
# MBA Universidade de São Paulo                        0.013872
# Faculdade de Administração Milton Campos             0.013872
# SP -> Centro Universitário de Santo André - UNIA     0.013872
# Name: proportion, Length: 682, dtype: float64
# ============================================================
# cursos
#                                                 14.842558
# Análise e Desenvolvimento de Sistemas            8.503260
# Ciência da Computação                            7.240949
# Sistemas de Informação                           6.186711
# Administração                                    5.312803
#                                                   ...
# Design de Interiores                             0.013872
# Ciências Atuariais                               0.013872
# Suprimentos                                      0.013872
# Executivo em Gerenciamento de Projetos           0.013872
# MBA em Controladoria e Finanças Corporativas     0.013872
# Name: proportion, Length: 158, dtype: float64
# ============================================================
# ano_conclusao
# 0       22.777084
# 2020     5.964766
# 2021     5.548620
# 2019     4.813428
# 2018     4.466639
#           ...
# 91       0.013872
# 9990     0.013872
# 420      0.013872
# 2110     0.013872
# 2204     0.013872
# Name: proportion, Length: 80, dtype: float64
# ============================================================

# %%
df.head()
# Out:
#   candidato_id        objetivo_profissional                 local  \
# 0        31000
# 1        31001      Analista Administrativo  São Paulo, São Paulo
# 2        31002  Administrativo | Financeiro  São Paulo, São Paulo
# 3        31003          Área administrativa  São Paulo, São Paulo
# 4        31004
#
#                       nome             nivel_academico   nivel_ingles  \
# 0       Carolina Aparecida
# 1             Eduardo Rios  Ensino Superior Incompleto         Nenhum
# 2  Pedro Henrique Carvalho    Ensino Superior Completo  Intermediário
# 3           Thiago Barbosa  Ensino Superior Incompleto         Nenhum
# 4          Diogo das Neves
#
#   nivel_espanhol         outro_idioma          titulo_profissional  \
# 0                                   -
# 1         Nenhum                    -      Analista Administrativo
# 2         Básico  Português - Fluente  Administrativo | Financeiro
# 3         Nenhum                    -          Área administrativa
# 4                                   -
#
#      area_atuacao conhecimentos_tecnicos  \
# 0
# 1  Administrativa
# 2  Administrativa
# 3  Administrativa
# 4
#
#                                        certificacoes outras_certificacoes  \
# 0
# 1
# 2  MS [77-418] MOS: Microsoft Office Word 2013, M...
# 3
# 4
#
#   nivel_profissional                                              cv_pt  \
# 0                     assistente administrativo\n\n\nsantosbatista\n...
# 1                     formação acadêmica\nensino médio (2º grau) em ...
# 2                     objetivo: área administrativa | financeira\n\n...
# 3                     formação\nensino médio completo\ninformática i...
# 4                     última atualização em 09/11/2021\n­ sp\n\nensi...
#
#   instituicao_ensino_superior                     cursos ano_conclusao
# 0                         NaN                        NaN           NaN
# 1                         NaN                        NaN           NaN
# 2                              Administração de Empresas          2012
# 3                         NaN                        NaN           NaN
# 4                         NaN                        NaN           NaN

# %% [markdown]
# # Tratamentos para o modelo
#
# * objetivo_profissional
# * local (separar cidade/estado)
# * nivel_academico (feature engineering)
# * nivel_ingles (buscar no cv_pt e feature engineering)
# * nivel_espanhol (buscar no cv_pt e feature engineering)
# * remuneracao (normalizar ou feature engineering)
# * nivel_profissional (feature engineering)

# %%
df.objetivo_profissional.value_counts(normalize=True) * 100
# Out:
# objetivo_profissional
#                                            33.934372
# Java                                        1.555953
# Gerente de Projetos                         1.428840
# Suporte                                     1.275834
# Desenvolvedor                               1.113413
#                                              ...
# Desenvolvedor Dot Net                       0.002354
# Administrativa/logística e ou comercial     0.002354
# BigData                                     0.002354
# Gerente TI                                  0.002354
# Analista de planejamento                    0.002354
# Name: proportion, Length: 8368, dtype: float64

# %%
df.local.value_counts(normalize=True) * 100
# Out:
# local
#                                   59.964220
# São Paulo, São Paulo              15.265289
# Rio de Janeiro, Rio de Janeiro     1.996140
# Fortaleza, Ceará                   1.876089
# Campinas, São Paulo                1.388824
#                                     ...
# Capixaba, Acre                     0.002354
# Sanclerlândia, Goiás               0.002354
# Mato Grosso                        0.002354
# São Marcos, Rio Grande do Sul      0.002354
# Palmas, Paraná                     0.002354
# Name: proportion, Length: 721, dtype: float64

# %%
def normalizar_local(local):
    # Garante que estamos trabalhando com uma string
    if not isinstance(local, str):
        return pd.Series(['Não informado', 'Não informado'])

    # Remove o padrão numérico do início (ex: '59.964220')
    # r'^\d+\.\d+' significa: no início da string (^), encontre um ou mais dígitos (\d+),
    # seguidos por um ponto literal (\.), seguido por um ou mais dígitos (\d+).
    texto_limpo = re.sub(r'^\d+\.\d+', '', local).strip()

    # Se após a limpeza não sobrar nada, retorna como não informado
    if not texto_limpo:
        return pd.Series(['Não informado', 'Não informado'])

    # Verifica se há uma vírgula para separar cidade e estado
    if ',' in texto_limpo:
        partes = texto_limpo.split(',', 1) # Divide apenas na primeira vírgula
        cidade = partes[0].strip()
        estado = partes[1].strip()
        return pd.Series([cidade, estado])
    else:
        # Se não houver vírgula, assume que é a cidade
        cidade = texto_limpo.strip()
        estado = 'Não informado'
        return pd.Series([cidade, estado])
    
df[['cidade', 'estado']] = df['local'].apply(normalizar_local)

# %%
df.estado.value_counts(normalize=True) * 100
# Out:
# estado
# Não informado          60.948166
# São Paulo              25.773269
# Rio de Janeiro          2.739984
# Minas Gerais            2.302151
# Ceará                   2.109129
# Bahia                   1.080458
# Paraná                  1.016901
# Distrito Federal        0.706181
# Pernambuco              0.668518
# Rio Grande do Sul       0.659103
# Santa Catarina          0.572007
# Goiás                   0.270703
# Maranhão                0.263641
# Espirito Santo          0.157714
# Paraíba                 0.141236
# Amazonas                0.089450
# Pará                    0.084742
# Rio Grande do Norte     0.063556
# Alagoas                 0.061202
# Mato Grosso             0.058848
# Sergipe                 0.058848
# Piauí                   0.051787
# Mato Grosso do Sul      0.047079
# Tocantins               0.032955
# Rondônia                0.016478
# Amapá                   0.014124
# Acre                    0.007062
# Roraima                 0.004708
# Name: proportion, dtype: float64

# %%
df.nivel_academico.value_counts(normalize=True) * 100
# Out:
# nivel_academico
#                                  80.947225
# Ensino Superior Completo          8.318817
# Pós Graduação Completo            4.267690
# Ensino Superior Cursando          2.111483
# Ensino Superior Incompleto        0.981592
# Ensino Médio Completo             0.943929
# Pós Graduação Cursando            0.680288
# Ensino Técnico Completo           0.529636
# Mestrado Completo                 0.386046
# Pós Graduação Incompleto          0.350737
# Ensino Técnico Cursando           0.127113
# Mestrado Incompleto               0.077680
# Mestrado Cursando                 0.063556
# Ensino Fundamental Completo       0.056495
# Ensino Técnico Incompleto         0.040017
# Doutorado Completo                0.028247
# Ensino Médio Incompleto           0.023539
# Ensino Médio Cursando             0.021185
# Doutorado Incompleto              0.018832
# Ensino Fundamental Cursando       0.009416
# Doutorado Cursando                0.009416
# Ensino Fundamental Incompleto     0.007062
# Name: proportion, dtype: float64

# %%
df.nivel_academico.unique()
# Out:
# array(['', 'Ensino Superior Incompleto', 'Ensino Superior Completo',
#        'Ensino Técnico Completo', 'Ensino Superior Cursando',
#        'Pós Graduação Completo', 'Pós Graduação Cursando',
#        'Pós Graduação Incompleto', 'Ensino Técnico Cursando',
#        'Ensino Fundamental Completo', 'Ensino Médio Completo',
#        'Doutorado Completo', 'Mestrado Completo', 'Mestrado Incompleto',
#        'Mestrado Cursando', 'Doutorado Incompleto',
#        'Ensino Técnico Incompleto', 'Ensino Médio Cursando',
#        'Ensino Médio Incompleto', 'Ensino Fundamental Cursando',
#        'Doutorado Cursando', 'Ensino Fundamental Incompleto'],
#       dtype=object)

# %%
def mapear_escolaridade_ordinal(coluna_nivel_academico: pd.Series) -> pd.Series:
    mapeamento_ordinal = {
        # Fundamental
        'Ensino Fundamental Incompleto': 1,
        'Ensino Fundamental Cursando': 2,
        'Ensino Fundamental Completo': 3,
        # Médio
        'Ensino Médio Incompleto': 4,
        'Ensino Médio Cursando': 5,
        'Ensino Médio Completo': 6,
        # Técnico
        'Ensino Técnico Incompleto': 7,
        'Ensino Técnico Cursando': 8,
        'Ensino Técnico Completo': 9,
        # Superior
        'Ensino Superior Incompleto': 10,
        'Ensino Superior Cursando': 11,
        'Ensino Superior Completo': 12,
        # Pós-Graduação / Especialização
        'Pós Graduação Incompleto': 13,
        'Pós Graduação Cursando': 14,
        'Pós Graduação Completo': 15,
        # Mestrado
        'Mestrado Incompleto': 16,
        'Mestrado Cursando': 17,
        'Mestrado Completo': 18,
        # Doutorado
        'Doutorado Incompleto': 19,
        'Doutorado Cursando': 20,
        'Doutorado Completo': 21
    }

    # Aplica o mapeamento, preenche valores não encontrados com 0 e converte para inteiro.
    coluna_ordinal = coluna_nivel_academico.map(mapeamento_ordinal).fillna(0).astype(int)

    return coluna_ordinal

df['ordem_escolaridade'] = mapear_escolaridade_ordinal(df['nivel_academico'])

# %%
def obter_nivel_idioma_pd(df: pd.DataFrame, coluna_primaria: str) -> pd.DataFrame:
    df_processado = df.copy()
    
    if 'ingles' in coluna_primaria.lower():
        idioma = 'ingles'
        regex_com_niveis = r"ingles\s*[:,\s]*\s*(basico|tecnico|intermediario|avancado|fluente)"
        regex_presenca = r"(?:ingles|english)"
    elif 'espanhol' in coluna_primaria.lower():
        idioma = 'espanhol'
        regex_com_niveis = r"espanhol\s*[:,\s]*\s*(basico|tecnico|intermediario|avancado|fluente)"
        regex_presenca = r"(?:espanhol|spanish)"
    else:
        raise ValueError(f"Não foi possível inferir o idioma da coluna '{coluna_primaria}'.")

    mapa_primario = {'Nenhum': 0, 'Básico': 1, 'Técnico': 2, 'Intermediário': 3, 'Avançado': 4, 'Fluente': 5}
    mapa_fallback = {'basico': 1, 'tecnico': 2, 'intermediario': 3, 'avancado': 4, 'fluente': 5}

    nivel_primario = pd.Series(index=df.index, dtype='float64') 
    if coluna_primaria in df_processado.columns:
        coluna_com_nans = df_processado[coluna_primaria].replace(r'^\s*$', np.nan, regex=True)
        nivel_primario = coluna_com_nans.str.title().map(mapa_primario)

    coluna_fallback_texto = 'cv_pt'
    nivel_fallback = pd.Series(index=df.index, dtype='float64')
    if coluna_fallback_texto in df_processado.columns:
        
        cv_lower = df_processado[coluna_fallback_texto].str.lower().fillna('')
        
        cv_normalizado = cv_lower.apply(
            lambda texto: ''.join(c for c in unicodedata.normalize('NFKD', texto) if not unicodedata.combining(c))
        )
        cv_normalizado = cv_normalizado.str.replace('\n', ' ', regex=False)

        niveis_extraidos = cv_normalizado.str.extract(regex_com_niveis, expand=True)[0]
        nivel_numerico_extraido = niveis_extraidos.map(mapa_fallback)
        
        presenca_detectada = cv_normalizado.str.contains(regex_presenca, na=False).astype(int)
        
        nivel_fallback = nivel_numerico_extraido.fillna(presenca_detectada)

    nivel_unificado = nivel_primario.fillna(nivel_fallback)
    df_processado[f"nivel_{idioma}_num"] = nivel_unificado.fillna(0).astype('Int8')

    return df_processado

# %%
df = obter_nivel_idioma_pd(df, 'nivel_ingles')
df = obter_nivel_idioma_pd(df, 'nivel_espanhol')

resultado_final_candidato = df[df['candidato_id'] == '31008']

print("--- Resultado final para o candidato 31008 (Após Correção Definitiva) ---")
print(resultado_final_candidato[['candidato_id', 'nivel_ingles', 'nivel_espanhol', 'nivel_ingles_num', 'nivel_espanhol_num']])
# Out:
# --- Resultado final para o candidato 31008 (Após Correção Definitiva) ---
#   candidato_id nivel_ingles nivel_espanhol  nivel_ingles_num  \
# 8        31008                                             1
#
#    nivel_espanhol_num
# 8                   0

# %%
df.columns
# Out:
# Index(['candidato_id', 'objetivo_profissional', 'local', 'nome',
#        'nivel_academico', 'nivel_ingles', 'nivel_espanhol', 'outro_idioma',
#        'titulo_profissional', 'area_atuacao', 'conhecimentos_tecnicos',
#        'certificacoes', 'outras_certificacoes', 'cv_pt',
#        'instituicao_ensino_superior', 'cursos', 'ano_conclusao', 'cidade',
#        'estado', 'ordem_escolaridade', 'nivel_ingles_num',
#        'nivel_espanhol_num'],
#       dtype='object')
