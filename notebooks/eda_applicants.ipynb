# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('../data/raw/applicants.json')

# %%
records = []
for key, value in df.items():
    record = {"id_candidato": key}
    for sub_key, sub_value in value.items():
        if isinstance(sub_value, dict):
            record.update(sub_value)
    records.append(record)

df = pd.DataFrame(records)

df.replace(['', ' ', '-', 'Nenhum -'], np.nan, inplace=True)
# Out:
# C:\Users\Mayko\AppData\Local\Temp\ipykernel_12408\3282250586.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(['', ' ', '-', 'Nenhum -'], np.nan, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42482 entries, 0 to 42481
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id_candidato                 42482 non-null  int64
#  1   telefone_recado              0 non-null      float64
#  2   telefone                     41026 non-null  object
#  3   objetivo_profissional        28065 non-null  object
#  4   data_criacao                 42480 non-null  object
#  5   inserido_por                 42482 non-null  object
#  6   email                        42482 non-null  object
#  7   local                        17008 non-null  object
#  8   sabendo_de_nos_por           20376 non-null  object
#  9   data_atualizacao             42480 non-null  object
#  10  codigo_profissional          42482 non-null  object
#  11  nome                         42482 non-null  object
#  12  data_aceite                  42482 non-null  object
#  13  cpf                          0 non-null      float64
#  14  fonte_indicacao              42482 non-null  object
#  15  email_secundario             0 non-null      float64
#  16  data_nascimento              42480 non-null  object
#  17  telefone_celular             41026 non-null  object
#  18  sexo                         7184 non-null   object
#  19  estado_civil                 7451 non-null   object
#  20  pcd                          6321 non-null   object
#  21  endereco                     16928 non-null  object
#  22  skype                        0 non-null      float64
#  23  url_linkedin                 0 non-null      float64
#  24  facebook                     0 non-null      float64
#  25  titulo_profissional          28065 non-null  object
#  26  area_atuacao                 6751 non-null   object
#  27  conhecimentos_tecnicos       3352 non-null   object
#  28  certificacoes                528 non-null    object
#  29  outras_certificacoes         898 non-null    object
#  30  remuneracao                  20136 non-null  object
#  31  nivel_profissional           80 non-null     object
#  32  nivel_academico              8094 non-null   object
#  33  nivel_ingles                 6844 non-null   object
#  34  nivel_espanhol               6687 non-null   object
#  35  outro_idioma                 1413 non-null   object
#  36  instituicao_ensino_superior  1249 non-null   object
#  37  cursos                       6139 non-null   object
#  38  ano_conclusao                7209 non-null   object
#  39  download_cv                  5562 non-null   object
#  40  qualificacoes                1 non-null      object
#  41  experiencias                 1 non-null      object
#  42  outro_curso                  809 non-null    object
#  43  id_ibrati                    396 non-null    object
#  44  email_corporativo            0 non-null      float64
#  45  cargo_atual                  398 non-null    object
#  46  projeto_atual                1 non-null      object
#  47  cliente                      398 non-null    object
#  48  unidade                      397 non-null    object
#  49  data_admissao                741 non-null    object
#  50  data_ultima_promocao         741 non-null    object
#  51  nome_superior_imediato       1 non-null      object
#  52  email_superior_imediato      1 non-null      object
# dtypes: float64(7), int64(1), object(45)
# memory usage: 17.2+ MB

# %%
df.columns
# Out:
# Index(['id_candidato', 'telefone_recado', 'telefone', 'objetivo_profissional',
#        'data_criacao', 'inserido_por', 'email', 'local', 'sabendo_de_nos_por',
#        'data_atualizacao', 'codigo_profissional', 'nome', 'data_aceite', 'cpf',
#        'fonte_indicacao', 'email_secundario', 'data_nascimento',
#        'telefone_celular', 'sexo', 'estado_civil', 'pcd', 'endereco', 'skype',
#        'url_linkedin', 'facebook', 'titulo_profissional', 'area_atuacao',
#        'conhecimentos_tecnicos', 'certificacoes', 'outras_certificacoes',
#        'remuneracao', 'nivel_profissional', 'nivel_academico', 'nivel_ingles',
#        'nivel_espanhol', 'outro_idioma', 'instituicao_ensino_superior',
#        'cursos', 'ano_conclusao', 'download_cv', 'qualificacoes',
#        'experiencias', 'outro_curso', 'id_ibrati', 'email_corporativo',
#        'cargo_atual', 'projeto_atual', 'cliente', 'unidade', 'data_admissao',
#        'data_ultima_promocao', 'nome_superior_imediato',
#        'email_superior_imediato'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        print(f"Column '{col}' has {df[col].nunique()} unique values.")
# Out:
# Column 'telefone' has 41025 unique values.
# Column 'objetivo_profissional' has 8366 unique values.
# Column 'data_criacao' has 41707 unique values.
# Column 'inserido_por' has 63 unique values.
# Column 'email' has 41482 unique values.
# Column 'local' has 720 unique values.
# Column 'sabendo_de_nos_por' has 13 unique values.
# Column 'data_atualizacao' has 41760 unique values.
# Column 'codigo_profissional' has 42482 unique values.
# Column 'nome' has 40686 unique values.
# Column 'data_aceite' has 11013 unique values.
# Column 'fonte_indicacao' has 2072 unique values.
# Column 'data_nascimento' has 6157 unique values.
# Column 'telefone_celular' has 41025 unique values.
# Column 'sexo' has 2 unique values.
# Column 'estado_civil' has 6 unique values.
# Column 'pcd' has 2 unique values.
# Column 'endereco' has 26 unique values.
# Column 'titulo_profissional' has 8366 unique values.
# Column 'area_atuacao' has 837 unique values.
# Column 'conhecimentos_tecnicos' has 3188 unique values.
# Column 'certificacoes' has 269 unique values.
# Column 'outras_certificacoes' has 882 unique values.
# Column 'remuneracao' has 3701 unique values.
# Column 'nivel_profissional' has 10 unique values.
# Column 'nivel_academico' has 21 unique values.
# Column 'nivel_ingles' has 5 unique values.
# Column 'nivel_espanhol' has 5 unique values.
# Column 'outro_idioma' has 32 unique values.
# Column 'instituicao_ensino_superior' has 681 unique values.
# Column 'cursos' has 157 unique values.
# Column 'ano_conclusao' has 80 unique values.
# Column 'download_cv' has 5409 unique values.
# Column 'qualificacoes' has 1 unique values.
# Column 'experiencias' has 1 unique values.
# Column 'outro_curso' has 1 unique values.
# Column 'id_ibrati' has 395 unique values.
# Column 'cargo_atual' has 60 unique values.
# Column 'projeto_atual' has 1 unique values.
# Column 'cliente' has 9 unique values.
# Column 'unidade' has 2 unique values.
# Column 'data_admissao' has 227 unique values.
# Column 'data_ultima_promocao' has 226 unique values.
# Column 'nome_superior_imediato' has 1 unique values.
# Column 'email_superior_imediato' has 1 unique values.

# %%
for column in df.columns:
    if df[column].nunique() < 10:
        print(f"Column '{column}' unique values: {df[column].unique()}")
# Out:
# Column 'telefone_recado' unique values: [nan]
# Column 'cpf' unique values: [nan]
# Column 'email_secundario' unique values: [nan]
# Column 'sexo' unique values: [nan 'Feminino' 'Masculino']
# Column 'estado_civil' unique values: [nan 'Solteiro' 'Casado' 'União Estável' 'Divorciado'
#  'Separado Judicialmente' 'Viúvo']
# Column 'pcd' unique values: [nan 'Não' 'Sim']
# Column 'skype' unique values: [nan]
# Column 'url_linkedin' unique values: [nan]
# Column 'facebook' unique values: [nan]
# Column 'nivel_ingles' unique values: [nan 'Nenhum' 'Intermediário' 'Básico' 'Avançado' 'Fluente']
# Column 'nivel_espanhol' unique values: [nan 'Nenhum' 'Básico' 'Intermediário' 'Avançado' 'Fluente']
# Column 'qualificacoes' unique values: [nan
#  'Profissional com mais de 10 anos de experiência em infraestrutura de TI (Administração e supervisão). Sólidos conhecimentos em programação JAVA, HTML, CSS, Java script, VB.NET, SQL SERVER e PL SQL. 12 anos de experiência em comércio Exterior (Importação, Exportação, Câmbio, Compra de mercadorias e embarques aéreos e marítimos.']
# Column 'experiencias' unique values: [nan
#  'Hyper IT – 07/2018 a Atualmente Cargo: Depende do projeto contratado – SEM VINCULO EMPREGATÍCIO Principais responsabilidades: 1 – Carrefour – Migração/Instalação do servidor (TPLinux), PDVs, Caixas, Balanças, terminal de consulta de preços, scanners, SAT, balcão e suporte pós migração (abertura, fechamento e rescaldo). 2 – Grupo Petrópolis – Migração de rack e instalação dos equipamentos da TIVIT. (Firewall Fortinet, Switch Cisco, Wnos Dell), suporte aos usuários pós migração e posteriormente no suporte às equipes nas migrações dos racks direto no escritório da TIVIT remotamente e via telefone. 3 – Caixa Econômica – Suporte de campo em manutenção de Totens de senha. 4 – Banco do Brasil – Suporte de campo na instalação e manutenção de Aps BB digital. 5 – GRSA – Suporte de campo em computadores desktop Dell, impressoras fiscais e SAT. 6 – FDE – Suporte de campo nos equipamentos de rede (firewall, switches e link de dados). 7 – Banco Itaú – Suporte de campo na manutenção do rack de rede. 8 – Embracon – Suporte de campo em rede e desktops Pablo Slemenson – 04/2013 a 04/2016 Motivo da saída/ interesse em sair: Mudança de CLT para prestador de serviço Cargo: Analista de Sistemas e Help Desk Principais responsabilidades: 1 Administração de servidores Windows e Linux: Samba, Apache, DNS, Active Directory, Impressão, FTP, servidor WEB ISS, VPN, virtualização com Hyper V e GPO. 2 Servidor de dados NAS com redundância de arquivos Iomega EMC2: Atualização de firmware, backup em nuvem, configuração em RAID, backup local, recuperação de arquivos, restauração de dados (Full, incremental e diferencial). 3 Cabeamento estruturado (dados, voz e telefonia): Lan, Wan, Wireless e telefonia (Estrutura Draytek, CISCO, IBM, FUROKAWA e HP). 4 Administração e manutenção de desktops e notebooks com S.O Variados: Windows, Mac OSX e Linux (Montagem, Instalação e Configuração) 5 Inventário de TI com OS Invetory e sistemas de chamados SLA com GLPI: Licenciamento de software, administração de contratos com prestadores de serviços e administração de fornecedores de equipamentos. 6 Treinamento de funcionários em ERP: Financeiro, Projetos, Comercial e Contábil. 7 Administração de servidor de E-mail Exchange server: Criação de e-mails, exclusão de e-mails e configuração de contas em computadores (outlook) e dispositivos moveis (Android, Apple e Windows). 8 Desenvolvimento em JAVA, VBA, VB.NET, WEB e SQL. 9 Desenvolvimento de planilhas em Excel com programação em VBA. 10 Segurança: Administração de antivírus server (Avira), firewall e controle de acesso web. 11 Gerenciamento e treinamento de equipe de TI (Help Desk). Massena Com. Exterior Ltda – 02/2001 a 12/2012 Motivo da saída/ interesse em sair: Sócio voltou para Angola Cargo: Sócio Principais responsabilidades: TI 1 Responsável pelo dep. de TI (servidores, redes e estações) no Brasil. 2 Supervisão e treinamento de equipes de TI em Angola (Implantação de Hardware ou Software) junto aos clientes (Governo Angolano). COMÉRCIO EXTERIOR 1 Recebimentos internacionais: fechamento de câmbio junto aos bancos, fechamento dos processos de câmbio junto ao banco central. 2 Cotações de fretes nacionais e internacionais: Terrestre, Marítimo e Aéreo. 3 Importação e Exportação de mercadorias e serviços. 4 Administração e pagamento de empresas prestadoras de serviços: Despachante aduaneiro, armazéns alfandegados e corretoras de câmbio ...etc 5 Confecção de Invoice, Packlist e NF. 6 Visitas a clientes e fornecedores: Brasil e Angola.']
# Column 'outro_curso' unique values: [nan 'Outro Curso:']
# Column 'email_corporativo' unique values: [nan]
# Column 'projeto_atual' unique values: [nan 'Carrefour']
# Column 'cliente' unique values: [nan 'DECISION IBM 15 07' 'DIEBOLD' 'IBM ESCOPO FECHADO' 'Diebold'
#  'T SYSTEMS' 'DECISION IBM 07' 'DECISION BOSCH 07' 'ACCENTURE'
#  'Infoserver']
# Column 'unidade' unique values: [nan 'Decision São Paulo' 'São Paulo']
# Column 'nome_superior_imediato' unique values: [nan 'Gabriel Pereira']
# Column 'email_superior_imediato' unique values: [nan 'gabriel@decisiongroup.com.br']

# %%
df = df.drop(
    ['telefone_recado',
     'telefone',
     'email',
     'cpf',
     'email_secundario',
     'telefone_celular',
     'skype',
     'url_linkedin',
     'facebook',
     'download_cv',
     'id_ibrati',
     'email_corporativo',
     'nome_superior_imediato',
     'email_superior_imediato',
     'nivel_profissional',
     'qualificacoes',
     'experiencias',
     'projeto_atual',
     'cliente'], axis=1)

# %%
pd.set_option('display.max_columns', None)
df.head(20)
# Out:
#     id_candidato                              objetivo_profissional  \
# 0          31000                                                NaN
# 1          31001                            Analista Administrativo
# 2          31002                        Administrativo | Financeiro
# 3          31003                                Área administrativa
# 4          31004                                                NaN
# 5          31005            Administrativa/logística e ou comercial
# 6          31006                 Analista Administrativo Financeiro
# 7          31007  Desejo fazer parte do time da empresa oferecen...
# 8          31008                                                NaN
# 9          31009                                                NaN
# 10         31010                                                NaN
# 11         31011             Trabalhar na área administrativa ou TI
# 12         31012                                                NaN
# 13         31013                                                NaN
# 14         31014                                                NaN
# 15         31015                    Atuar com redes de computadores
# 16         31016                                                NaN
# 17         31017                         Analista de Infraestrutura
# 18         31018                                                NaN
# 19         31019                                                NaN
#
#            data_criacao            inserido_por                         local  \
# 0   10-11-2021 07:29:49            Luna Correia                           NaN
# 1   10-11-2021 08:56:16           Laura Pacheco          São Paulo, São Paulo
# 2   10-11-2021 09:01:00           Laura Pacheco          São Paulo, São Paulo
# 3   10-11-2021 09:08:13           Laura Pacheco          São Paulo, São Paulo
# 4   10-11-2021 09:18:46       Maria Clara Pires                           NaN
# 5   10-11-2021 09:19:56              Clara Rios          São Paulo, São Paulo
# 6   10-11-2021 09:22:20              Clara Rios          São Paulo, São Paulo
# 7   10-11-2021 09:27:18              Clara Rios  Belo Horizonte, Minas Gerais
# 8   10-11-2021 09:32:58       Maria Clara Pires                           NaN
# 9   10-11-2021 09:39:27       Maria Clara Pires                           NaN
# 10  10-11-2021 09:49:39      Natália Cavalcanti                           NaN
# 11  10-11-2021 10:00:14  pelo próprio candidato        Carapicuíba, São Paulo
# 12  10-11-2021 10:00:59            Luna Correia                           NaN
# 13  10-11-2021 10:02:23      Natália Cavalcanti                           NaN
# 14  10-11-2021 10:12:02              Clara Rios                           NaN
# 15  10-11-2021 10:12:22  pelo próprio candidato          Guarulhos, São Paulo
# 16  10-11-2021 10:48:53           Lunna Fonseca                           NaN
# 17  10-11-2021 11:03:59              Clara Rios          São Paulo, São Paulo
# 18  10-11-2021 11:08:51        Emanuella Campos                           NaN
# 19  10-11-2021 12:04:47    Ana Beatriz Caldeira                           NaN
#
#    sabendo_de_nos_por     data_atualizacao codigo_profissional  \
# 0                 NaN  10-11-2021 07:29:49               31000
# 1              Outros  11-11-2021 11:10:31               31001
# 2             Anúncio  10-11-2021 11:42:36               31002
# 3    Site de Empregos  10-11-2021 16:04:51               31003
# 4                 NaN  10-11-2021 09:22:03               31004
# 5    Site de Empregos  10-11-2021 16:54:03               31005
# 6    Site de Empregos  13-11-2021 00:27:53               31006
# 7              Outros  10-11-2021 11:49:11               31007
# 8                 NaN  10-11-2021 09:32:58               31008
# 9                 NaN  10-11-2021 09:39:27               31009
# 10                NaN  14-02-2022 16:33:17               31010
# 11             Indeed  30-03-2022 22:44:42               31011
# 12                NaN  10-11-2021 10:00:59               31012
# 13                NaN  25-11-2021 17:29:19               31013
# 14                NaN  10-11-2021 10:12:02               31014
# 15             Indeed  10-11-2021 10:12:22               31015
# 16                NaN  10-11-2021 10:48:53               31016
# 17             Outros  10-11-2021 11:27:24               31017
# 18                NaN  13-12-2021 16:55:40               31018
# 19                NaN  10-11-2021 12:04:47               31019
#
#                        nome                              data_aceite  \
# 0        Carolina Aparecida  Cadastro anterior ao registro de aceite
# 1              Eduardo Rios  Cadastro anterior ao registro de aceite
# 2   Pedro Henrique Carvalho  Cadastro anterior ao registro de aceite
# 3            Thiago Barbosa  Cadastro anterior ao registro de aceite
# 4           Diogo das Neves  Cadastro anterior ao registro de aceite
# 5              Maya Fonseca  Cadastro anterior ao registro de aceite
# 6          Thomas Rodrigues  Cadastro anterior ao registro de aceite
# 7   Pedro Miguel Nascimento  Cadastro anterior ao registro de aceite
# 8            Ágatha Pereira  Cadastro anterior ao registro de aceite
# 9              Paulo Novaes  Cadastro anterior ao registro de aceite
# 10       Davi Lucca Sampaio  Cadastro anterior ao registro de aceite
# 11       Srta. Aylla Campos                         30/03/2022 22:44
# 12             Apollo Alves  Cadastro anterior ao registro de aceite
# 13       Eduarda Montenegro  Cadastro anterior ao registro de aceite
# 14          Bárbara Fonseca  Cadastro anterior ao registro de aceite
# 15             Gael da Mota  Cadastro anterior ao registro de aceite
# 16         Davi Lucas Porto  Cadastro anterior ao registro de aceite
# 17   Dra. Ana Júlia Barbosa  Cadastro anterior ao registro de aceite
# 18               Théo Cunha  Cadastro anterior ao registro de aceite
# 19    Srta. Stella Teixeira  Cadastro anterior ao registro de aceite
#
#                       fonte_indicacao data_nascimento       sexo estado_civil  \
# 0                                   :      0000-00-00        NaN          NaN
# 1               Outros: Contato do RH      28-12-1994   Feminino     Solteiro
# 2                            Anúncio:      12-12-1988   Feminino     Solteiro
# 3          Site de Empregos: Infojobs      08-05-1992   Feminino       Casado
# 4                                   :      31-12-1969        NaN          NaN
# 5                   Site de Empregos:      24-12-1979   Feminino       Casado
# 6                   Site de Empregos:      12-09-1990  Masculino     Solteiro
# 7   Outros: Me chamaram pelo WhatsApp      09-04-1995   Feminino       Casado
# 8                                   :      0000-00-00        NaN          NaN
# 9                                   :      0000-00-00        NaN          NaN
# 10                                  :      0000-00-00        NaN          NaN
# 11                            Indeed:      03-03-1978  Masculino          NaN
# 12                                  :      0000-00-00        NaN          NaN
# 13                                  :      0000-00-00        NaN          NaN
# 14                                  :      0000-00-00        NaN          NaN
# 15                            Indeed:      21-04-1983   Feminino     Solteiro
# 16                                  :      0000-00-00        NaN          NaN
# 17                   Outros: Whatsapp      23-06-1999  Masculino     Solteiro
# 18                                  :      31-12-1969        NaN          NaN
# 19                                  :      0000-00-00        NaN          NaN
#
#     pcd      endereco                                titulo_profissional  \
# 0   NaN           NaN                                                NaN
# 1   Não     são paulo                            Analista Administrativo
# 2   Não     são paulo                        Administrativo | Financeiro
# 3   Não     são paulo                                Área administrativa
# 4   NaN           NaN                                                NaN
# 5   NaN     são paulo            Administrativa/logística e ou comercial
# 6   NaN     são paulo                 Analista Administrativo Financeiro
# 7   Não  minas gerais  Desejo fazer parte do time da empresa oferecen...
# 8   NaN           NaN                                                NaN
# 9   NaN           NaN                                                NaN
# 10  NaN           NaN                                                NaN
# 11  NaN     são paulo             Trabalhar na área administrativa ou TI
# 12  NaN           NaN                                                NaN
# 13  NaN           NaN                                                NaN
# 14  NaN           NaN                                                NaN
# 15  Não     são paulo                    Atuar com redes de computadores
# 16  NaN           NaN                                                NaN
# 17  Não     são paulo                         Analista de Infraestrutura
# 18  NaN           NaN                                                NaN
# 19  NaN           NaN                                                NaN
#
#                                          area_atuacao  \
# 0                                                 NaN
# 1                                      Administrativa
# 2                                      Administrativa
# 3                                      Administrativa
# 4                                                 NaN
# 5                                           Comercial
# 6                            Financeira/Controladoria
# 7   Administrativa, Comercial, Financeira/Controla...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                     Administrativa
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  TI - Arquitetura, TI - Infraestrutura, TI - Pr...
# 16                                                NaN
# 17                                TI - Infraestrutura
# 18                                                NaN
# 19                                                NaN
#
#                                conhecimentos_tecnicos  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                              Roteadores, Switches.
# 16                                                NaN
# 17  - Redes; - Sistemas Operacionais (Windows, Lin...
# 18                                                NaN
# 19                                                NaN
#
#                                         certificacoes  \
# 0                                                 NaN
# 1                                                 NaN
# 2   MS [77-418] MOS: Microsoft Office Word 2013, M...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  Cisco Certified Network Professional - CCNP, C...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#         outras_certificacoes remuneracao             nivel_academico  \
# 0                        NaN         NaN                         NaN
# 1                        NaN        1900  Ensino Superior Incompleto
# 2                        NaN    2.500,00    Ensino Superior Completo
# 3                        NaN     1100,00  Ensino Superior Incompleto
# 4                        NaN         NaN                         NaN
# 5                        NaN     2000,00     Ensino Técnico Completo
# 6   SAP, DN4,MICROSIGA,TOTVS        2800    Ensino Superior Cursando
# 7                        NaN     1688,00    Ensino Superior Completo
# 8                        NaN         NaN                         NaN
# 9                        NaN         NaN                         NaN
# 10                       NaN         NaN                         NaN
# 11                       NaN    1.800,00    Ensino Superior Completo
# 12                       NaN         NaN                         NaN
# 13                       NaN         NaN                         NaN
# 14                       NaN         NaN                         NaN
# 15                       NaN    R$12.000      Pós Graduação Completo
# 16                       NaN         NaN                         NaN
# 17                       NaN   R$2100,00    Ensino Superior Completo
# 18                       NaN         NaN                         NaN
# 19                       NaN         NaN                         NaN
#
#      nivel_ingles nivel_espanhol         outro_idioma  \
# 0             NaN            NaN                  NaN
# 1          Nenhum         Nenhum                  NaN
# 2   Intermediário         Básico  Português - Fluente
# 3          Nenhum         Nenhum                  NaN
# 4             NaN            NaN                  NaN
# 5          Básico         Básico                  NaN
# 6          Nenhum  Intermediário                  NaN
# 7          Nenhum         Nenhum  Português - Fluente
# 8             NaN            NaN                  NaN
# 9             NaN            NaN                  NaN
# 10            NaN            NaN                  NaN
# 11         Básico         Nenhum                  NaN
# 12            NaN            NaN                  NaN
# 13            NaN            NaN                  NaN
# 14            NaN            NaN                  NaN
# 15       Avançado       Avançado                  NaN
# 16            NaN            NaN                  NaN
# 17         Básico         Básico                  NaN
# 18            NaN            NaN                  NaN
# 19            NaN            NaN                  NaN
#
#    instituicao_ensino_superior                              cursos  \
# 0                          NaN                                 NaN
# 1                          NaN                                 NaN
# 2                          NaN           Administração de Empresas
# 3                          NaN                                 NaN
# 4                          NaN                                 NaN
# 5                          NaN                                 NaN
# 6                          NaN                   Gestão Financeira
# 7                          NaN                           Logística
# 8                          NaN                                 NaN
# 9                          NaN                                 NaN
# 10                         NaN                                 NaN
# 11                         NaN            Tecnologia da Informação
# 12                         NaN                                 NaN
# 13                         NaN                                 NaN
# 14                         NaN                                 NaN
# 15                         NaN      Engenharia de telecomunicações
# 16                         NaN                                 NaN
# 17                         NaN  Gestão da Tecnologia da Informação
# 18                         NaN                                 NaN
# 19                         NaN                                 NaN
#
#    ano_conclusao outro_curso cargo_atual unidade data_admissao  \
# 0            NaN         NaN         NaN     NaN           NaN
# 1            NaN         NaN         NaN     NaN           NaN
# 2           2012         NaN         NaN     NaN           NaN
# 3            NaN         NaN         NaN     NaN           NaN
# 4            NaN         NaN         NaN     NaN           NaN
# 5              0         NaN         NaN     NaN           NaN
# 6           2011         NaN         NaN     NaN           NaN
# 7              0         NaN         NaN     NaN           NaN
# 8            NaN         NaN         NaN     NaN           NaN
# 9            NaN         NaN         NaN     NaN           NaN
# 10           NaN         NaN         NaN     NaN           NaN
# 11          2007         NaN         NaN     NaN           NaN
# 12           NaN         NaN         NaN     NaN           NaN
# 13           NaN         NaN         NaN     NaN           NaN
# 14           NaN         NaN         NaN     NaN           NaN
# 15          2011         NaN         NaN     NaN           NaN
# 16           NaN         NaN         NaN     NaN           NaN
# 17          2020         NaN         NaN     NaN           NaN
# 18           NaN         NaN         NaN     NaN           NaN
# 19           NaN         NaN         NaN     NaN           NaN
#
#    data_ultima_promocao
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
