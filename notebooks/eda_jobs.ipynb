# %%
import os
import json
import pandas as pd
import unicodedata

# %%
FILE = '../data/raw/jobs.json'

def load_json(path):
    with open(path, 'r', encoding='utf-8') as f:
        return json.load(f)

# Applicants
data = load_json(FILE)
df = pd.DataFrame([
    {
        'vaga_id': job_id,
        **job.get('informacoes_basicas', {}),
        **job.get('perfil_vaga', {}),
        **job.get('beneficios', {}),
    }
    for job_id, job in data.items()
])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14081 entries, 0 to 14080
# Data columns (total 45 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   vaga_id                                  14081 non-null  object
#  1   data_requicisao                          14081 non-null  object
#  2   limite_esperado_para_contratacao         14081 non-null  object
#  3   titulo_vaga                              14081 non-null  object
#  4   vaga_sap                                 14081 non-null  object
#  5   cliente                                  14081 non-null  object
#  6   solicitante_cliente                      14081 non-null  object
#  7   empresa_divisao                          14081 non-null  object
#  8   requisitante                             14081 non-null  object
#  9   analista_responsavel                     14081 non-null  object
#  10  tipo_contratacao                         14081 non-null  object
#  11  prazo_contratacao                        14081 non-null  object
#  12  objetivo_vaga                            14081 non-null  object
#  13  prioridade_vaga                          14081 non-null  object
#  14  origem_vaga                              14081 non-null  object
#  15  superior_imediato                        14039 non-null  object
#  16  nome                                     9625 non-null   object
#  17  telefone                                 9319 non-null   object
#  18  pais                                     14081 non-null  object
#  19  estado                                   14081 non-null  object
#  20  cidade                                   14081 non-null  object
#  21  bairro                                   14081 non-null  object
#  22  regiao                                   14081 non-null  object
#  23  local_trabalho                           14081 non-null  object
#  24  vaga_especifica_para_pcd                 14081 non-null  object
#  25  faixa_etaria                             14081 non-null  object
#  26  horario_trabalho                         14081 non-null  object
#  27  nivel profissional                       14081 non-null  object
#  28  nivel_academico                          14081 non-null  object
#  29  nivel_ingles                             14081 non-null  object
#  30  nivel_espanhol                           14081 non-null  object
#  31  outro_idioma                             14081 non-null  object
#  32  areas_atuacao                            14081 non-null  object
#  33  principais_atividades                    14081 non-null  object
#  34  competencia_tecnicas_e_comportamentais   14081 non-null  object
#  35  demais_observacoes                       14081 non-null  object
#  36  viagens_requeridas                       14081 non-null  object
#  37  equipamentos_necessarios                 11396 non-null  object
#  38  valor_venda                              14081 non-null  object
#  39  valor_compra_1                           14081 non-null  object
#  40  valor_compra_2                           14081 non-null  object
#  41  data_inicial                             4456 non-null   object
#  42  data_final                               4456 non-null   object
#  43  habilidades_comportamentais_necessarias  2685 non-null   object
#  44  nome_substituto                          348 non-null    object
# dtypes: object(45)
# memory usage: 4.8+ MB

# %%
df.columns
# Out:
# Index(['vaga_id', 'data_requicisao', 'limite_esperado_para_contratacao',
#        'titulo_vaga', 'vaga_sap', 'cliente', 'solicitante_cliente',
#        'empresa_divisao', 'requisitante', 'analista_responsavel',
#        'tipo_contratacao', 'prazo_contratacao', 'objetivo_vaga',
#        'prioridade_vaga', 'origem_vaga', 'superior_imediato', 'nome',
#        'telefone', 'pais', 'estado', 'cidade', 'bairro', 'regiao',
#        'local_trabalho', 'vaga_especifica_para_pcd', 'faixa_etaria',
#        'horario_trabalho', 'nivel profissional', 'nivel_academico',
#        'nivel_ingles', 'nivel_espanhol', 'outro_idioma', 'areas_atuacao',
#        'principais_atividades', 'competencia_tecnicas_e_comportamentais',
#        'demais_observacoes', 'viagens_requeridas', 'equipamentos_necessarios',
#        'valor_venda', 'valor_compra_1', 'valor_compra_2', 'data_inicial',
#        'data_final', 'habilidades_comportamentais_necessarias',
#        'nome_substituto'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        print(f"Column '{col}' has {df[col].nunique()} unique values.")
# Out:
# Column 'vaga_id' has 14081 unique values.
# Column 'data_requicisao' has 1543 unique values.
# Column 'limite_esperado_para_contratacao' has 1306 unique values.
# Column 'titulo_vaga' has 12452 unique values.
# Column 'vaga_sap' has 2 unique values.
# Column 'cliente' has 112 unique values.
# Column 'solicitante_cliente' has 311 unique values.
# Column 'empresa_divisao' has 2 unique values.
# Column 'requisitante' has 24 unique values.
# Column 'analista_responsavel' has 63 unique values.
# Column 'tipo_contratacao' has 40 unique values.
# Column 'prazo_contratacao' has 3 unique values.
# Column 'objetivo_vaga' has 6 unique values.
# Column 'prioridade_vaga' has 4 unique values.
# Column 'origem_vaga' has 3 unique values.
# Column 'superior_imediato' has 1 unique values.
# Column 'nome' has 81 unique values.
# Column 'telefone' has 4 unique values.
# Column 'pais' has 1 unique values.
# Column 'estado' has 27 unique values.
# Column 'cidade' has 167 unique values.
# Column 'bairro' has 133 unique values.
# Column 'regiao' has 11 unique values.
# Column 'local_trabalho' has 2 unique values.
# Column 'vaga_especifica_para_pcd' has 3 unique values.
# Column 'faixa_etaria' has 9 unique values.
# Column 'horario_trabalho' has 34 unique values.
# Column 'nivel profissional' has 14 unique values.
# Column 'nivel_academico' has 16 unique values.
# Column 'nivel_ingles' has 6 unique values.
# Column 'nivel_espanhol' has 7 unique values.
# Column 'outro_idioma' has 17 unique values.
# Column 'areas_atuacao' has 74 unique values.
# Column 'principais_atividades' has 11710 unique values.
# Column 'competencia_tecnicas_e_comportamentais' has 11552 unique values.
# Column 'demais_observacoes' has 6729 unique values.
# Column 'viagens_requeridas' has 3 unique values.
# Column 'equipamentos_necessarios' has 7 unique values.
# Column 'valor_venda' has 861 unique values.
# Column 'valor_compra_1' has 955 unique values.
# Column 'valor_compra_2' has 41 unique values.
# Column 'data_inicial' has 848 unique values.
# Column 'data_final' has 1244 unique values.
# Column 'habilidades_comportamentais_necessarias' has 1839 unique values.
# Column 'nome_substituto' has 263 unique values.

# %%
df = df.drop(
    ['data_requicisao',
    'limite_esperado_para_contratacao',
    'cliente',
    'solicitante_cliente',
    'empresa_divisao',
    'requisitante',
    'analista_responsavel',
    'telefone',
    'pais',
    'superior_imediato'
    ]
     , axis=1)

# %%
for column in df.columns:
    if df[column].nunique() < 41:
        print(f"Column '{column}' unique values: {df[column].unique()}")
# Out:
# Column 'vaga_sap' unique values: ['Não' 'Sim']
# Column 'tipo_contratacao' unique values: ['CLT Full' 'PJ/Autônomo, CLT Full' 'PJ/Autônomo' 'CLT Cotas' 'Cooperado'
#  'Hunting' 'Hunting, PJ/Autônomo, CLT Full' 'PJ/Autônomo, CLT Cotas'
#  'CLT Full, PJ/Autônomo' 'PJ/Autônomo, Hunting' 'PJ/Autônomo, Cooperado'
#  'Cooperado, PJ/Autônomo' 'CLT Full, CLT Cotas, PJ/Autônomo' 'Estagiário'
#  'PJ/Autônomo, Cooperado, CLT Cotas' 'Hunting, PJ/Autônomo' ''
#  'Candidato poderá escolher, PJ/Autônomo'
#  'PJ/Autônomo, Cooperado, CLT Full' 'CLT Full, Cooperado, PJ/Autônomo'
#  'CLT Full, Hunting' 'Hunting, PJ/Autônomo, Cooperado'
#  'Candidato poderá escolher, Hunting, PJ/Autônomo' 'Cooperado, CLT Full'
#  'CLT Cotas, PJ/Autônomo' 'CLT Full, Cooperado'
#  'CLT Full, CLT Cotas, Cooperado, Estagiário, PJ/Autônomo'
#  'Hunting, CLT Full' 'PJ/Autônomo, CLT Cotas, CLT Full'
#  'CLT Cotas, CLT Full' 'CLT Full, CLT Cotas'
#  'CLT Cotas, Cooperado, Estagiário, PJ/Autônomo'
#  'CLT Cotas, Cooperado, Estagiário, PJ/Autônomo, Hunting'
#  'CLT Full, CLT Cotas, Cooperado, Estagiário, PJ/Autônomo, Hunting'
#  'CLT Full, CLT Cotas, Cooperado, PJ/Autônomo'
#  'PJ/Autônomo, Cooperado, CLT Cotas, CLT Full' 'CLT Cotas, Cooperado'
#  'CLT Full, CLT Cotas, Cooperado, Estagiário'
#  'PJ/Autônomo, Estagiário, Cooperado, CLT Cotas, CLT Full'
#  'Cooperado, CLT Cotas']
# Column 'prazo_contratacao' unique values: ['' 'Determinado' 'Indeterminado']
# Column 'objetivo_vaga' unique values: ['' 'Contratação' 'RFP' 'Prospecção' 'Ordem de Serviço' 'Parcerias']
# Column 'prioridade_vaga' unique values: ['' 'Alta: Alta complexidade 3 a 5 dias'
#  'Média: Média complexidade 6 a 10 dias'
#  'Baixa: Baixa complexidade 11 a 30 dias']
# Column 'origem_vaga' unique values: ['' 'Nova Posição' 'Substituição']
# Column 'estado' unique values: ['São Paulo' 'Paraná' 'Pernambuco' 'Minas Gerais' 'Rio de Janeiro'
#  'Rio Grande do Sul' 'Ceará' 'Rondônia' 'Distrito Federal' 'Paraíba'
#  'Alagoas' 'Bahia' 'Mato Grosso' 'Sergipe' 'Santa Catarina' '' 'Amazonas'
#  'Piauí' 'Acre' 'Pará' 'Maranhão' 'Espirito Santo' 'Goiás'
#  'Rio Grande do Norte' 'Amapá' 'Mato Grosso do Sul' 'Tocantins']
# Column 'regiao' unique values: ['' 'Oeste' 'Sul' 'Centro' 'Leste' 'Outra' 'Grande São Paulo' 'ABC'
#  'Niterói' 'Baixada Santista' 'Norte']
# Column 'local_trabalho' unique values: ['2000' '1000']
# Column 'vaga_especifica_para_pcd' unique values: ['Não' 'Sim' '']
# Column 'faixa_etaria' unique values: ['De: Até:' 'De: 22 Até: 32' 'De: 18 Até: 40' 'De: 18 Até: 30'
#  'De: 25 Até: 50' 'De: 25 Até: 45' 'De: 26 Até: 45' 'De: 20 Até: 40'
#  'De: 20 Até: 42']
# Column 'horario_trabalho' unique values: ['' '9 as 18' 'Comercial' '09h as 187h' '09 horas as 18 horas'
#  '08:30 às 12:30 hrs / 14:00 às 18:00 hrs' '9 às 18 hs' '8:00 às 17:00'
#  'Comercial - 09h às 18h segunda a sexta'
#  'hibrido 3 x por semana na Franciso Matarazzo proxi'
#  'Horário Comercial: das 8 às 18 horas' 'Horário Comercial' '8 a 17'
#  'Atuação em São Bernardo do Campo - entre Pampas e' 'Das 11h às 20h'
#  '02 vagas - Das 09h às 18h e das 10 às 19h' 'DAS 09:00 AS 18:00'
#  '8 as 18' '9/18' 'das *9 as 18hs' 'Das 9 às 18hs'
#  'Vide descrição da vaga' '09:00 as 18:00' '08:00 as 17:00'
#  'Horario comercial' 'comercial' '6x1 / madrugada 5x2' '9/18 14/22'
#  '9 AS 18' 'de segunda a domingo, das 22:00 às 06:00 horas com'
#  '8:00am to 5:00pm' 'Vaga para cobertura de licença maternidade, em tor'
#  '8/17' '9h as 18h']
# Column 'nivel profissional' unique values: ['Sênior' 'Analista' 'Pleno' 'Coordenador' 'Especialista' 'Gerente'
#  'Supervisor' 'Assistente' 'Líder' 'Júnior' 'Aprendiz' 'Auxiliar'
#  'Trainee' 'Técnico de Nível Médio']
# Column 'nivel_academico' unique values: ['Ensino Superior Completo' 'Ensino Médio Completo'
#  'Ensino Técnico Completo' 'Ensino Superior Cursando'
#  'Ensino Superior Incompleto' 'Pós Graduação Completo'
#  'Doutorado Cursando' 'Pós Graduação Incompleto' 'Doutorado Completo'
#  'Ensino Técnico Cursando' 'Pós Graduação Cursando' 'Mestrado Completo'
#  'Ensino Fundamental Completo' 'Ensino Médio Incompleto'
#  'Ensino Técnico Incompleto' 'Mestrado Cursando']
# Column 'nivel_ingles' unique values: ['Avançado' 'Fluente' 'Nenhum' 'Básico' 'Intermediário' 'Técnico']
# Column 'nivel_espanhol' unique values: ['Fluente' 'Nenhum' 'Intermediário' 'Básico' 'Avançado' '' 'Técnico']
# Column 'outro_idioma' unique values: ['' 'Mandarim ou Russo' 'Nenhum' 'Avançado' 'Português Fluente'
#  'Português Avançado' 'Português Básico' 'Francês Básico' 'Fluente'
#  'Básico' 'Francês Intermediário' 'Mandarim - Desejável' 'Alemão Fluente'
#  'Francês Fluente' 'Alemão Avançado' 'Português Intermediário' 'Português']
# Column 'viagens_requeridas' unique values: ['' 'Não' 'Sim']
# Column 'equipamentos_necessarios' unique values: ['Nenhum -' 'Notebook padrão -' nan '' 'Notebook top -' 'Outro -'
#  'Notebook padrão - Celular/Smartphone -' 'Outro - Nenhum -']

# %%
df = df.drop(
    ['regiao',
     'local_trabalho',
     'faixa_etaria',
     'horario_trabalho',
     'viagens_requeridas',
     'equipamentos_necessarios'
     ], axis=1)

# %%
df.columns
# Out:
# Index(['vaga_id', 'titulo_vaga', 'vaga_sap', 'tipo_contratacao',
#        'prazo_contratacao', 'objetivo_vaga', 'prioridade_vaga', 'origem_vaga',
#        'nome', 'estado', 'cidade', 'bairro', 'vaga_especifica_para_pcd',
#        'nivel profissional', 'nivel_academico', 'nivel_ingles',
#        'nivel_espanhol', 'outro_idioma', 'areas_atuacao',
#        'principais_atividades', 'competencia_tecnicas_e_comportamentais',
#        'demais_observacoes', 'valor_venda', 'valor_compra_1', 'valor_compra_2',
#        'data_inicial', 'data_final', 'habilidades_comportamentais_necessarias',
#        'nome_substituto'],
#       dtype='object')

# %%
for col in df.columns:
    print(df[col].value_counts(normalize=True) * 100)
    print("=" * 60)
# Out:
# vaga_id
# 12364    0.007102
# 12380    0.007102
# 12381    0.007102
# 12382    0.007102
# 12383    0.007102
#            ...
# 5180     0.007102
# 5181     0.007102
# 5182     0.007102
# 5183     0.007102
# 5184     0.007102
# Name: proportion, Length: 14081, dtype: float64
# ============================================================
# titulo_vaga
# PROXXI JR                          0.568141
# SAP SD                             0.390597
# PROXXI                             0.319580
# Desenvolvedor Java                 0.198850
# SAP MM                             0.198850
#                                      ...
# Especialista FI - SV-147           0.007102
# Gerente de Integrações - SV-146    0.007102
# CPI/PO SV-145                      0.007102
# Gerente de Projetos - SV-144       0.007102
# Technical Architect - 11894809     0.007102
# Name: proportion, Length: 12452, dtype: float64
# ============================================================
# vaga_sap
# Não    95.078475
# Sim     4.921525
# Name: proportion, dtype: float64
# ============================================================
# tipo_contratacao
# PJ/Autônomo                                                         28.868688
# CLT Full                                                            22.370570
# CLT Full, PJ/Autônomo                                               15.169377
# PJ/Autônomo, CLT Full                                                9.090263
# Hunting                                                              8.742277
# Cooperado                                                            5.560685
#                                                                      4.289468
# CLT Cotas                                                            2.940132
# Cooperado, PJ/Autônomo                                               0.589447
# CLT Full, Cooperado, PJ/Autônomo                                     0.468717
# PJ/Autônomo, Cooperado                                               0.447411
# PJ/Autônomo, CLT Cotas                                               0.262765
# CLT Cotas, Cooperado, Estagiário, PJ/Autônomo                        0.120730
# CLT Full, CLT Cotas, PJ/Autônomo                                     0.120730
# CLT Cotas, PJ/Autônomo                                               0.120730
# CLT Cotas, Cooperado, Estagiário, PJ/Autônomo, Hunting               0.099425
# CLT Full, CLT Cotas, Cooperado, PJ/Autônomo                          0.099425
# CLT Full, CLT Cotas, Cooperado, Estagiário, PJ/Autônomo              0.092323
# PJ/Autônomo, Cooperado, CLT Cotas                                    0.078119
# PJ/Autônomo, Cooperado, CLT Full                                     0.063916
# CLT Full, CLT Cotas                                                  0.056814
# CLT Cotas, CLT Full                                                  0.056814
# CLT Full, Cooperado                                                  0.049712
# PJ/Autônomo, CLT Cotas, CLT Full                                     0.042611
# PJ/Autônomo, Hunting                                                 0.028407
# Estagiário                                                           0.021305
# CLT Cotas, Cooperado                                                 0.021305
# Hunting, PJ/Autônomo, CLT Full                                       0.014204
# CLT Full, Hunting                                                    0.014204
# Hunting, PJ/Autônomo                                                 0.014204
# PJ/Autônomo, Estagiário, Cooperado, CLT Cotas, CLT Full              0.014204
# Hunting, PJ/Autônomo, Cooperado                                      0.014204
# Cooperado, CLT Full                                                  0.007102
# Candidato poderá escolher, Hunting, PJ/Autônomo                      0.007102
# Candidato poderá escolher, PJ/Autônomo                               0.007102
# Hunting, CLT Full                                                    0.007102
# PJ/Autônomo, Cooperado, CLT Cotas, CLT Full                          0.007102
# CLT Full, CLT Cotas, Cooperado, Estagiário, PJ/Autônomo, Hunting     0.007102
# CLT Full, CLT Cotas, Cooperado, Estagiário                           0.007102
# Cooperado, CLT Cotas                                                 0.007102
# Name: proportion, dtype: float64
# ============================================================
# prazo_contratacao
# Indeterminado    37.802713
# Determinado      31.645480
#                  30.551807
# Name: proportion, dtype: float64
# ============================================================
# objetivo_vaga
# Contratação         77.068390
#                     21.923159
# Prospecção           0.681770
# RFP                  0.298274
# Parcerias            0.021305
# Ordem de Serviço     0.007102
# Name: proportion, dtype: float64
# ============================================================
# prioridade_vaga
# Alta: Alta complexidade 3 a 5 dias        60.606491
#                                           28.762162
# Média: Média complexidade 6 a 10 dias      7.598892
# Baixa: Baixa complexidade 11 a 30 dias     3.032455
# Name: proportion, dtype: float64
# ============================================================
# origem_vaga
# Nova Posição    61.004190
#                 36.524395
# Substituição     2.471415
# Name: proportion, dtype: float64
# ============================================================
# nome
#                                       98.618182
# Zé Carlos                              0.166234
# Felipe                                 0.051948
# Piton                                  0.041558
# Layla Lima                             0.031169
#                                         ...
# Wesley                                 0.010390
# profissionais para sistemas legado     0.010390
# PORTAL PRESTADOR                       0.010390
# Alexsandro                             0.010390
# Deborah Hoffman                        0.010390
# Name: proportion, Length: 81, dtype: float64
# ============================================================
# estado
# São Paulo              79.625027
# Minas Gerais            5.312123
# Rio de Janeiro          4.445707
# Pernambuco              4.438605
# Paraná                  1.548185
# Ceará                   1.306725
# Rio Grande do Sul       0.830907
# Santa Catarina          0.575243
# Distrito Federal        0.440310
# Amazonas                0.333783
# Bahia                   0.220155
# Goiás                   0.106527
# Maranhão                0.099425
# Paraíba                 0.099425
# Pará                    0.092323
# Espirito Santo          0.092323
#                         0.078119
# Mato Grosso             0.063916
# Rondônia                0.042611
# Alagoas                 0.042611
# Sergipe                 0.042611
# Piauí                   0.042611
# Mato Grosso do Sul      0.035509
# Acre                    0.028407
# Rio Grande do Norte     0.028407
# Amapá                   0.014204
# Tocantins               0.014204
# Name: proportion, dtype: float64
# ============================================================
# cidade
# São Paulo         66.394432
# Recife             4.424402
# Rio de Janeiro     4.033804
# Hortolândia        3.138982
# Nova Lima          2.989844
#                     ...
# Itatiba            0.007102
# Eunápolis          0.007102
# Paulo Afonso       0.007102
# Parnamirim         0.007102
# Suzano             0.007102
# Name: proportion, Length: 167, dtype: float64
# ============================================================
# bairro
#                          92.251971
# Chácara Santo Antônio     2.386194
# Recife Antigo             0.653363
# Alphaville                0.511327
# Vila da Serra             0.468717
#                            ...
# trabalho remoto           0.007102
# Jardim Carvalho           0.007102
# Vila Yara                 0.007102
# Dionísio Torres           0.007102
# Demarchi                  0.007102
# Name: proportion, Length: 133, dtype: float64
# ============================================================
# vaga_especifica_para_pcd
# Não    86.023720
#        13.834245
# Sim     0.142035
# Name: proportion, dtype: float64
# ============================================================
# nivel profissional
# Sênior                    37.618067
# Analista                  37.511540
# Pleno                     15.084156
# Júnior                     4.523826
# Especialista               2.819402
# Assistente                 1.029756
# Gerente                    0.575243
# Líder                      0.440310
# Supervisor                 0.156239
# Coordenador                0.149137
# Auxiliar                   0.049712
# Aprendiz                   0.021305
# Trainee                    0.014204
# Técnico de Nível Médio     0.007102
# Name: proportion, dtype: float64
# ============================================================
# nivel_academico
# Ensino Superior Completo       78.062638
# Ensino Médio Completo          10.361480
# Ensino Superior Cursando        4.978340
# Ensino Técnico Completo         4.665862
# Ensino Superior Incompleto      1.235708
# Pós Graduação Completo          0.362190
# Pós Graduação Cursando          0.092323
# Ensino Médio Incompleto         0.063916
# Pós Graduação Incompleto        0.049712
# Ensino Fundamental Completo     0.042611
# Ensino Técnico Incompleto       0.021305
# Ensino Técnico Cursando         0.021305
# Mestrado Completo               0.021305
# Doutorado Cursando              0.007102
# Doutorado Completo              0.007102
# Mestrado Cursando               0.007102
# Name: proportion, dtype: float64
# ============================================================
# nivel_ingles
# Básico           35.189262
# Nenhum           26.361764
# Avançado         17.939067
# Fluente          10.347276
# Intermediário     8.806193
# Técnico           1.356438
# Name: proportion, dtype: float64
# ============================================================
# nivel_espanhol
# Nenhum           43.690079
# Básico           41.339394
#                   9.260706
# Avançado          2.357787
# Intermediário     1.661814
# Fluente           1.612101
# Técnico           0.078119
# Name: proportion, dtype: float64
# ============================================================
# outro_idioma
#                            97.351040
# Português Básico            1.185995
# Português Fluente           0.674668
# Básico                      0.291173
# Português Avançado          0.120730
# Nenhum                      0.099425
# Português                   0.071018
# Mandarim - Desejável        0.063916
# Francês Fluente             0.049712
# Português Intermediário     0.028407
# Alemão Avançado             0.014204
# Avançado                    0.014204
# Mandarim ou Russo           0.007102
# Fluente                     0.007102
# Francês Básico              0.007102
# Alemão Fluente              0.007102
# Francês Intermediário       0.007102
# Name: proportion, dtype: float64
# ============================================================
# areas_atuacao
# TI - Projetos-                                                                                          35.970457
# TI - SAP-                                                                                               26.326255
# Gestão e Alocação de Recursos de TI-                                                                     9.750728
# TI - Desenvolvimento/Programação-                                                                        9.012144
# Administrativa-                                                                                          5.972587
#                                                                                                           ...
# TI - Desenvolvimento/Programação-TI - Qualidade/Testes-                                                  0.007102
# Administrativa-Comercial-                                                                                0.007102
# TI - Desenvolvimento/Mobile-TI - Desenvolvimento/Programação-                                            0.007102
# TI - Infraestrutura-TI - Processos e Negócios-TI - Projetos-                                             0.007102
# TI - SAP-TI - Sistemas e Ferramentas-TI - Suporte-TI - Telecom-TI - UX-TI - Segurança da Informação-     0.007102
# Name: proportion, Length: 74, dtype: float64
# ============================================================
# principais_atividades
# Recebimento, separação e armazenamento de produtos, conhecimento em cadastro de nota fiscal, conhecimento básico em informática para manuseio de sistema empresarial                                                                                                                                                                                                                                                                                                                                                                                                                                   1.001349
# .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.262765
# Recebimento, separação e armazenagem de peças, inclusão de NF no sistema, possuir conhecimento básico em informatica para manuseio de sistema operacional.                                                                                                                                                                                                                                                                                                                                                                                                                                             0.213053
# Recebimento, separação e armazenamento de produtos, conhecimento em cadastro de nota fiscal, conhecimento básico em informática para manuseio de sistema empresarial.                                                                                                                                                                                                                                                                                                                                                                                                                                  0.163341
# Design, build and configure applications to meet business process and application requirements.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.134934
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# Conhecimento geral de processos de controle com integração logística, de preferência com know-how em material ledger e avaliação de estoque.\nLocalização de relatórios e impostos Brasil (foco de vendas) - Suporte à definição de requisitos fiscais, estatutários e de relatórios, integração com outros sistemas SAP e soluções de satélite locais.\nConhecimento em S/4 Hana mandatório. Experiência em projetos globais e definição de templates.\nConhecimento e experiencia em CO e Localização Brasil\n\nInglês Fluente (mandatório, pois irá interagir intensamente com equipes globais).    0.007102
# 100% remoto\n\nMandatório inglês fluente                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.007102
# "* Experiência em Rollout de template Europa para o Brasil (Template Global);\n\n* Experiência em Industria Automotiva (Carros e Caminhões);\n\n* Conhecimento de Localização Brasil;\n\n* Conhecimento do Idioma inglês para conversação ( será necessário interagir e atuar com equipe na Alemanha );\n\n* Conhecimento em modelagem e especificação de interfaces SAP x Sistemas Legados;\n\n* Conhecimento da metodologia de projetos SAP ACTIVATE;\n\n* Conhecimento em MRP "\n\n\nProjeto do ECC para o S4HANA                                                                                   0.007102
# - 5+ years proven experience as an SAP PP DS and QM Consultant with hands-on experience in implementing and supporting SAP PP DS and QM solutions.\n- Minimum 2 to 3 End to End implementation project experience\n- Speak both English and Portuguese Language\n- Extensive experience of different advance planning & detailed scheduling scenario like Block Planning, Campaign Planning, Model Mix Planning & Sequencing, Tank Planning & Optimizer.                                                                                                                                               0.007102
# desc-email                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             0.007102
# Name: proportion, Length: 11710, dtype: float64
# ============================================================
# competencia_tecnicas_e_comportamentais
# Recebimento, separação e armazenamento de produtos, conhecimento em cadastro de nota fiscal, conhecimento básico em informática para manuseio de sistema empresarial                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.887721
# .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.411903
# Horas: 8:00am to 5:00pm\n\nPrimary Skill * Others (Please note the Skill at the beginning of Job Description)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.355088
# Recebimento, separação e armazenagem de peças, inclusão de NF no sistema, possuir conhecimento básico em informatica para manuseio de sistema operacional.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.213053
# Recebimento, separação e armazenamento de produtos, conhecimento em cadastro de nota fiscal, conhecimento básico em informática para manuseio de sistema empresarial.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              0.163341
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# Experiência em Logistica.\nAtividades de Roterização dentro do Brasil.\nMandatório Inglês avançado/fluente (conversação)\n\n\nDesejável:\n\nConhecimento em sistema SAP\nExperiência com liderança\nEspanhol                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.007102
# Experiência em Logistica.\nAtividades de Roterização dentro do Brasil.\nMandatório Inglês avançado/fluente (conversação)\nEspanhol - desejável\nDesejável conhecimento em sistema SAP\nExperiência comprovada com gestão de pessoas/liderança                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0.007102
# Responsabilidades:\n\nProfissional senior de machine learning capaz de projetar, desenvolver e implementar modelos de ML complexos para resolver problemas específicos dos negócios, utilizando Python e bibliotecas relevantes (TensorFlow, PyTorch).\n\nTrabalhar em estreita colaboração com equipes de dados, produto e desenvolvimento para entender as necessidades dos negócios e integrar soluções de ML em nossa plataforma.\n\nImplementar melhores práticas de engenharia de software, incluindo Design Patterns e princípios SOLID, para garantir código de alta qualidade e fácil manutenção.\n\n\nQualificações Essenciais:\n\nExperiência sólida em programação com Python.\n\nProfundo conhecimento em Design Patterns, princípios SOLID e práticas avançadas de engenharia de software.\n\nConhecimento prático em plataformas de nuvem (Azure) e experiência com ferramentas de CI/CD.\n\nInglês obrigatório.    0.007102
# - Strong integration knowledge of integration with Logistics, procurement, inventory management, sales controlling & plant maintenance\n- Able to configure and customize SAP QM functionalities such as quality inspections, notifications, and quality control plans to ensure compliance with quality standards and regulations\n- Proficiency in SAP PP DS and QM configuration, including master data setup, scheduling strategies, planning board, DS board, Different profiles, PPDS Subcontracting process, alerts configuration & monitoring and quality management settings.                                                                                                                                                                                                                                                                                                                                             0.007102
# São Bernardo do Campo (Hibrido)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.007102
# Name: proportion, Length: 11552, dtype: float64
# ============================================================
# demais_observacoes
#                                                                                                                                                                                                                                                                                                       30.367161
# Budgeted Rate - indicate currency and type (hourly/daily)* TBD                                                                                                                                                                                                                                         5.219800
# Budgeted Rate - indicate currency and type (hourly/daily)* TBD: a ser determinada                                                                                                                                                                                                                      0.774093
# Remoto                                                                                                                                                                                                                                                                                                 0.355088
# Local = Remoto                                                                                                                                                                                                                                                                                         0.333783
#                                                                                                                                                                                                                                                                                                         ...
# Período: 3 meses com possibilidade de prorrogação Cte: Capgemini Remuneração máx: R$18.000,00 (CTPS 4K + verbas) Enviar CV com número de CPF e data de nascimento Atualização: PJ, trabalharemos baseados nas pretensões, negociadas, e a atuação será part time de 2 a 3x na semana, remotamente.     0.007102
# Cliente: Capgemini Vaga Hunting Grade: B1 Faixa salarial: (B1) R$ 4.100 a 4.900,00 Benefícios informados em e-mail específico para a vaga                                                                                                                                                              0.007102
# Observações: Cliente: Capgemini Vaga Hunting Grade: B2 Faixa salarial: (B2) R$ 5.900 a 7.100,00 Benefícios informados em e-mail específico para a vaga                                                                                                                                                 0.007102
# Área de Atuação Profissional: TI - Banco de Dados, TI - Desenvolvimento/Programação Tecnologia: Python, Design Patterns, SOLID Período: 6 meses, com possibilidade de prorrogação. Cliente: NTT Data Trabalharemos com as pretensões, negociadas Vínculo: PJ ou Cooperativa                            0.007102
# Classification: Confidential Remoto mas caso o cliente precise que vá ao escritório a pessoa concorde em ir. Seriam situações raras/pontuais.                                                                                                                                                          0.007102
# Name: proportion, Length: 6729, dtype: float64
# ============================================================
# valor_venda
# -                              41.999858
# - p/ mês (168h)                27.775016
# 168 -                           6.767985
# 168 - p/ hora                   3.749734
# 168 - p/ mês (168h)             1.129181
#                                  ...
# R$ 2.804,00 - p/ mês (176h)     0.007102
# 2804 - p/ mês (176h)            0.007102
# Ass.Adm.PL - p/ mês (168h)      0.007102
# 5300,00 - p/ mês (168h)         0.007102
# 3500,00 - p/ mês (168h)         0.007102
# Name: proportion, Length: 861, dtype: float64
# ============================================================
# valor_compra_1
# Fechado                                  20.105106
# R$                                       12.314466
# Aberto                                   10.290462
# hora                                      7.137277
# valor fechado.                            6.633052
#                                            ...
# R$ 126,00                                 0.007102
# R$ 65,00/hora                             0.007102
# 4500,00                                   0.007102
# Valor Aberto - SOMENTE PJ ou CLT FULL     0.007102
# 88 COMPRA                                 0.007102
# Name: proportion, Length: 955, dtype: float64
# ============================================================
# valor_compra_2
#                                                                                         99.666217
# 115,00                                                                                   0.014204
# 70,00                                                                                    0.014204
# 54,00                                                                                    0.014204
# 75,00                                                                                    0.014204
# 50,00                                                                                    0.014204
# 59,52                                                                                    0.014204
# 127,00                                                                                   0.014204
# 89,28                                                                                    0.007102
# 183,00                                                                                   0.007102
# Somente PJ ou CLT FULL                                                                   0.007102
# CLT Full ou PJ                                                                           0.007102
# Taxa máxima retirada devido a dificuldade dos parceiros de encontrar perfis pra vaga     0.007102
# CLT FULL ou PJ                                                                           0.007102
# 138,00                                                                                   0.007102
# SÓ PJ                                                                                    0.007102
# R$ 5.500,00                                                                              0.007102
# 165,00                                                                                   0.007102
# 53,57                                                                                    0.007102
# 65,47                                                                                    0.007102
# 102,00                                                                                   0.007102
# 67,00                                                                                    0.007102
# 58,00                                                                                    0.007102
# 3000,00                                                                                  0.007102
# Obs = Calcular remuneração de 2700 + 300 de auxilio transporte                           0.007102
# 125,00                                                                                   0.007102
# 101,19                                                                                   0.007102
# 150,00                                                                                   0.007102
# 3.000,00 dependendo da experiência                                                       0.007102
# mês R$12.000,00                                                                          0.007102
# PARA MAIOR DETALHAMENTO, VER EMAIL ENVIADO PELA CARMEM                                   0.007102
# 95,00                                                                                    0.007102
# 100,00                                                                                   0.007102
# 0                                                                                        0.007102
# CLT + Beneficios                                                                         0.007102
# 111,60                                                                                   0.007102
# 41,66                                                                                    0.007102
# 48,00                                                                                    0.007102
# 9.400,00                                                                                 0.007102
# 5500,00                                                                                  0.007102
# até R$12.200,00                                                                          0.007102
# Name: proportion, dtype: float64
# ============================================================
# data_inicial
# 30-11-0001    3.186715
# 03-01-2022    1.234291
# 01-12-2021    1.234291
# 01-02-2022    1.009874
# 01-11-2021    0.964991
#                 ...
# 18-06-2024    0.022442
# 11-06-2024    0.022442
# 24-04-2024    0.022442
# 15-08-2024    0.022442
# 17-04-2024    0.022442
# Name: proportion, Length: 848, dtype: float64
# ============================================================
# data_final
# 30-11-0001    3.209156
# 31-12-2024    1.862657
# 31-12-2021    1.256732
# 31-12-2022    1.211849
# 31-05-2022    1.166966
#                 ...
# 22-05-2025    0.022442
# 26-07-2024    0.022442
# 22-08-2024    0.022442
# 19-10-2025    0.022442
# 20-11-2023    0.022442
# Name: proportion, Length: 1244, dtype: float64
# ============================================================
# habilidades_comportamentais_necessarias
# HootSuite                                                                                                                                                                                                                                                                                                                                                                                                                                                     1.042831
# Remoto                                                                                                                                                                                                                                                                                                                                                                                                                                                        1.005587
# Remoto,                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.968343
#                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.819367
# Remoto, precisa de maquina                                                                                                                                                                                                                                                                                                                                                                                                                                    0.782123
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 1. Cliente name : J&J\n2. Contractor job code: TBC\n3. Job Title (platform / module / experience level): Machine Learning Engineer (MLOps Expert)\n4. Number of open positions: 1\n5. Project location (city / state / remote service or not / planning after pandemic): São Paulo, remote service\n7. Duration of the project: Initially, until end of year, with high probability of extension to 2022\n8. Start date expected / allocation or C2H: ASAP    0.037244
# ingles fluente,100% remota (mesmo depois da pandemia – qualquer lugar do BR)\nSalário até R$ 15.000,00 + benefícios                                                                                                                                                                                                                                                                                                                                           0.037244
# Tempo de projeto = 2 Meses\n\nRequested start date30.04.2021\nScheduled project end date30.06.2021                                                                                                                                                                                                                                                                                                                                                            0.037244
# Tempo de projeto = 6 meses\nValores:\nClt = R$ 3k\nPJ = R$ 35,00/h\n\n\n\n\nRequested start date01.06.2021\nScheduled project end date31.12.2021                                                                                                                                                                                                                                                                                                              0.037244
# Skill Junior-Pleno                                                                                                                                                                                                                                                                                                                                                                                                                                            0.037244
# Name: proportion, Length: 1839, dtype: float64
# ============================================================
# nome_substituto
#                                    21.839080
# Fernanda Sanches da Silva           0.574713
# Marcos Pucci                        0.574713
# Anna Lyro                           0.574713
# Diego Carvalho                      0.574713
#                                      ...
# Viviane Oliveira São Martinho       0.287356
# Amanda Elias Da Fonseca Marques     0.287356
# Daniel Freitas Araújo Júnior        0.287356
# Taynara Vieira Damião               0.287356
# Giovanna Peixoto                    0.287356
# Name: proportion, Length: 263, dtype: float64
# ============================================================

# %%
df = df.drop(
    ['objetivo_vaga',
     'prioridade_vaga',
     'origem_vaga',
     'bairro',
     'vaga_especifica_para_pcd',
     'data_inicial',
     'data_final',
     'nome_substituto',
     'prazo_contratacao',
     'areas_atuacao',
     'valor_venda',
     'valor_compra_1',
     'valor_compra_2',
     'outro_idioma'
     ], axis=1)

# %%
df.columns
# Out:
# Index(['vaga_id', 'titulo_vaga', 'vaga_sap', 'tipo_contratacao', 'nome',
#        'estado', 'cidade', 'nivel profissional', 'nivel_academico',
#        'nivel_ingles', 'nivel_espanhol', 'principais_atividades',
#        'competencia_tecnicas_e_comportamentais', 'demais_observacoes',
#        'habilidades_comportamentais_necessarias'],
#       dtype='object')

# %% [markdown]
# # Tratamentos para o modelo
#
# * vaga_sap (feature engineering)
# * tipo_contratacao (feature engineering)
# * prazo_contratacao (feature engineering)
# * nivel profissional (feature engineering)
# * nivel_academico (feature engineering)
# * nivel_ingles (feature engineering)
# * nivel_espanhol (feature engineering)

# %%
df.vaga_sap.value_counts(normalize=True) * 100
# Out:
# vaga_sap
# Não    95.078475
# Sim     4.921525
# Name: proportion, dtype: float64

# %%
def mapear_sim_nao(coluna: pd.Series) -> pd.Series:
    # 1. Cria o mapa: 'Sim' -> 1.
    mapa = {'Sim': 1}
    
    # 2. Padroniza a coluna para Title Case ('sim' -> 'Sim') para garantir o match.
    # 3. Aplica o mapa. Tudo que não for 'Sim' se tornará NaN.
    # 4. Preenche os valores NaN com 0.
    # 5. Converte o tipo da coluna para inteiro.
    coluna_numerica = coluna.str.title().map(mapa).fillna(0).astype('int8')
    
    return coluna_numerica

# %%
df['vaga_sap_num'] = mapear_sim_nao(df['vaga_sap'])

# %%
df.tipo_contratacao.value_counts(normalize=True) * 100
# Out:
# tipo_contratacao
# PJ/Autônomo                                                         28.868688
# CLT Full                                                            22.370570
# CLT Full, PJ/Autônomo                                               15.169377
# PJ/Autônomo, CLT Full                                                9.090263
# Hunting                                                              8.742277
# Cooperado                                                            5.560685
#                                                                      4.289468
# CLT Cotas                                                            2.940132
# Cooperado, PJ/Autônomo                                               0.589447
# CLT Full, Cooperado, PJ/Autônomo                                     0.468717
# PJ/Autônomo, Cooperado                                               0.447411
# PJ/Autônomo, CLT Cotas                                               0.262765
# CLT Cotas, Cooperado, Estagiário, PJ/Autônomo                        0.120730
# CLT Full, CLT Cotas, PJ/Autônomo                                     0.120730
# CLT Cotas, PJ/Autônomo                                               0.120730
# CLT Cotas, Cooperado, Estagiário, PJ/Autônomo, Hunting               0.099425
# CLT Full, CLT Cotas, Cooperado, PJ/Autônomo                          0.099425
# CLT Full, CLT Cotas, Cooperado, Estagiário, PJ/Autônomo              0.092323
# PJ/Autônomo, Cooperado, CLT Cotas                                    0.078119
# PJ/Autônomo, Cooperado, CLT Full                                     0.063916
# CLT Full, CLT Cotas                                                  0.056814
# CLT Cotas, CLT Full                                                  0.056814
# CLT Full, Cooperado                                                  0.049712
# PJ/Autônomo, CLT Cotas, CLT Full                                     0.042611
# PJ/Autônomo, Hunting                                                 0.028407
# Estagiário                                                           0.021305
# CLT Cotas, Cooperado                                                 0.021305
# Hunting, PJ/Autônomo, CLT Full                                       0.014204
# CLT Full, Hunting                                                    0.014204
# Hunting, PJ/Autônomo                                                 0.014204
# PJ/Autônomo, Estagiário, Cooperado, CLT Cotas, CLT Full              0.014204
# Hunting, PJ/Autônomo, Cooperado                                      0.014204
# Cooperado, CLT Full                                                  0.007102
# Candidato poderá escolher, Hunting, PJ/Autônomo                      0.007102
# Candidato poderá escolher, PJ/Autônomo                               0.007102
# Hunting, CLT Full                                                    0.007102
# PJ/Autônomo, Cooperado, CLT Cotas, CLT Full                          0.007102
# CLT Full, CLT Cotas, Cooperado, Estagiário, PJ/Autônomo, Hunting     0.007102
# CLT Full, CLT Cotas, Cooperado, Estagiário                           0.007102
# Cooperado, CLT Cotas                                                 0.007102
# Name: proportion, dtype: float64

# %%
df.tipo_contratacao.unique()
# Out:
# array(['CLT Full', 'PJ/Autônomo, CLT Full', 'PJ/Autônomo', 'CLT Cotas',
#        'Cooperado', 'Hunting', 'Hunting, PJ/Autônomo, CLT Full',
#        'PJ/Autônomo, CLT Cotas', 'CLT Full, PJ/Autônomo',
#        'PJ/Autônomo, Hunting', 'PJ/Autônomo, Cooperado',
#        'Cooperado, PJ/Autônomo', 'CLT Full, CLT Cotas, PJ/Autônomo',
#        'Estagiário', 'PJ/Autônomo, Cooperado, CLT Cotas',
#        'Hunting, PJ/Autônomo', '',
#        'Candidato poderá escolher, PJ/Autônomo',
#        'PJ/Autônomo, Cooperado, CLT Full',
#        'CLT Full, Cooperado, PJ/Autônomo', 'CLT Full, Hunting',
#        'Hunting, PJ/Autônomo, Cooperado',
#        'Candidato poderá escolher, Hunting, PJ/Autônomo',
#        'Cooperado, CLT Full', 'CLT Cotas, PJ/Autônomo',
#        'CLT Full, Cooperado',
#        'CLT Full, CLT Cotas, Cooperado, Estagiário, PJ/Autônomo',
#        'Hunting, CLT Full', 'PJ/Autônomo, CLT Cotas, CLT Full',
#        'CLT Cotas, CLT Full', 'CLT Full, CLT Cotas',
#        'CLT Cotas, Cooperado, Estagiário, PJ/Autônomo',
#        'CLT Cotas, Cooperado, Estagiário, PJ/Autônomo, Hunting',
#        'CLT Full, CLT Cotas, Cooperado, Estagiário, PJ/Autônomo, Hunting',
#        'CLT Full, CLT Cotas, Cooperado, PJ/Autônomo',
#        'PJ/Autônomo, Cooperado, CLT Cotas, CLT Full',
#        'CLT Cotas, Cooperado',
#        'CLT Full, CLT Cotas, Cooperado, Estagiário',
#        'PJ/Autônomo, Estagiário, Cooperado, CLT Cotas, CLT Full',
#        'Cooperado, CLT Cotas'], dtype=object)

# %%
def mapear_tipo_contratacao(coluna_contratacao: pd.Series) -> pd.Series:
    """
    Mapeia os tipos de contratação para um código numérico, tratando casos múltiplos como 'Híbrido'.

    Legenda: 0:Não Informado, 1:CLT, 2:PJ, 3:Cooperado, 4:Hunting, 5:Estagiário, 6:Híbrido
    """
    
    # Dicionário de busca. A ordem importa para a lógica if/elif.
    mapa_busca = {
        'clt': 1,
        'pj': 2,
        'cooperado': 3,
        'hunting': 4,
        'estagiario': 5,
    }

    def classificar_contratacao(valor):
        # Lida com valores nulos ou não-string
        if pd.isna(valor):
            return 0
        
        # Normaliza o texto para busca
        texto = str(valor).lower()
        texto = ''.join(c for c in unicodedata.normalize('NFKD', texto) if not unicodedata.combining(c))

        # Se o texto estiver vazio após a normalização, é 'Não Informado'
        if not texto.strip():
            return 0

        # Verifica a presença de cada palavra-chave
        tipos_encontrados = [palavra for palavra in mapa_busca if palavra in texto]
        
        # Aplica a lógica de classificação
        if len(tipos_encontrados) > 1:
            return 6 # Híbrido
        elif len(tipos_encontrados) == 1:
            palavra_encontrada = tipos_encontrados[0]
            return mapa_busca[palavra_encontrada]
        else:
            return 0 # Não Informado / Outros

    return coluna_contratacao.apply(classificar_contratacao)

# %%
df['contratacao_num'] = mapear_tipo_contratacao(df['tipo_contratacao'])

# %%
df['nivel profissional'].value_counts(normalize=True) * 100
# Out:
# nivel profissional
# Sênior                    37.618067
# Analista                  37.511540
# Pleno                     15.084156
# Júnior                     4.523826
# Especialista               2.819402
# Assistente                 1.029756
# Gerente                    0.575243
# Líder                      0.440310
# Supervisor                 0.156239
# Coordenador                0.149137
# Auxiliar                   0.049712
# Aprendiz                   0.021305
# Trainee                    0.014204
# Técnico de Nível Médio     0.007102
# Name: proportion, dtype: float64

# %%
df['nivel profissional'].unique()
# Out:
# array(['Sênior', 'Analista', 'Pleno', 'Coordenador', 'Especialista',
#        'Gerente', 'Supervisor', 'Assistente', 'Líder', 'Júnior',
#        'Aprendiz', 'Auxiliar', 'Trainee', 'Técnico de Nível Médio'],
#       dtype=object)

# %%
def mapear_nivel_profissional(coluna_nivel: pd.Series) -> pd.Series:
    """
    Mapeia uma coluna de texto de nível profissional para uma representação ordinal numérica.

    Args:
        coluna_nivel (pd.Series): A coluna do DataFrame com os níveis profissionais.

    Returns:
        pd.Series: Uma nova coluna com os valores ordinais correspondentes.
    """
    # Dicionário com a hierarquia de senioridade
    mapa_ordinal = {
        'Aprendiz': 1,
        'Auxiliar': 2,
        'Assistente': 3,
        'Trainee': 4,
        'Júnior': 5,
        'Técnico de Nível Médio': 6,
        'Pleno': 7,
        'Sênior': 8,
        'Especialista': 9,
        'Líder': 10,
        'Supervisor': 11,
        'Coordenador': 12,
        'Gerente': 13,
        'Outro': 0  # 'Outro' será considerado como 'Não Informado'
    }

    # Aplica o mapa. Valores não encontrados (como '' ou nulos) se tornarão NaN.
    coluna_numerica = coluna_nivel.map(mapa_ordinal)
    
    # Preenche os valores NaN com 0 e converte para um tipo inteiro.
    return coluna_numerica.fillna(0).astype('int8')

# %%
df['nivel_profissional_num'] = mapear_nivel_profissional(df['nivel profissional'])

# %%
df.columns
# Out:
# Index(['vaga_id', 'titulo_vaga', 'vaga_sap', 'tipo_contratacao', 'nome',
#        'estado', 'cidade', 'nivel profissional', 'nivel_academico',
#        'nivel_ingles', 'nivel_espanhol', 'principais_atividades',
#        'competencia_tecnicas_e_comportamentais', 'demais_observacoes',
#        'habilidades_comportamentais_necessarias', 'vaga_sap_num',
#        'contratacao_num', 'nivel_profissional_num'],
#       dtype='object')
